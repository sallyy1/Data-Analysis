# %%
from skimage import io
from matplotlib import pyplot as plt

# %%
# 데이터 불러오기
img = io.imread("xray exercise.jpeg")
io.imshow(img)
plt.show()

# %%
# 색상 모듈
from skimage import data, io, color
img_hsv = color.rgb2gray(img)  # rgb2gray() 함수
io.imshow(img_gray)
io.show()

# %%
img_hsv = color.rgb2hsv(img)  # rgb2hsv() 함수
io.imshow(img_hsv)
io.show()

# %%
img_green = color.rgb2green(img)  # rgb2green() 함수
io.imshow(img_green)
io.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b132be7f5180> in <module>
# ----> 1 img_green = color.rgb2green(img)  # rgb2hsv() 함수
#       2 io.imshow(img_green)
#       3 io.show()
#
# AttributeError: module 'skimage.color' has no attribute 'rgb2green'

# %%
# Constast Stretching 적용 코드

# %%
# Example Python Program for contrast stretching

from PIL import Image

 

# Method to process the red band of the image

def normalizeRed(intensity):

    iI      = intensity

   

    minI    = 86

    maxI    = 230

 

    minO    = 0

    maxO    = 255

 

    iO      = (iI-minI)*(((maxO-minO)/(maxI-minI))+minO)

    return iO

 

# Method to process the green band of the image

def normalizeGreen(intensity):

    iI      = intensity

   

    minI    = 90

    maxI    = 225

 

    minO    = 0

    maxO    = 255

 

    iO      = (iI-minI)*(((maxO-minO)/(maxI-minI))+minO)

    return iO

 

# Method to process the blue band of the image

def normalizeBlue(intensity):

    iI      = intensity

   

    minI    = 100

    maxI    = 210

 

    minO    = 0

    maxO    = 255

 

    iO      = (iI-minI)*(((maxO-minO)/(maxI-minI))+minO)

    return iO

 

 

# Create an image object

imageObject     = Image.open("xray exercise.jpeg")

 

# Split the red, green and blue bands from the Image

multiBands      = imageObject.split()

 

# Apply point operations that does contrast stretching on each color band

normalizedRedBand      = multiBands[0].point(normalizeRed)

normalizedGreenBand    = multiBands[1].point(normalizeGreen)

normalizedBlueBand     = multiBands[2].point(normalizeBlue)

 

# Create a new image from the contrast stretched red, green and blue brands

normalizedImage = Image.merge("RGB", (normalizedRedBand, normalizedGreenBand, normalizedBlueBand))

 

# Display the image before contrast stretching

imageObject.show()

 

# Display the image after contrast stretching

normalizedImage.show()

# %%
io.imsave("constast xray exercise.jpeg", normalizedImage)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-96d4effbf52a> in <module>
# ----> 1 io.imsave("constast xray exercise.jpeg", normalizedImage)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/skimage/io/_io.py in imsave(fname, arr, plugin, check_contrast, **plugin_args)
#     127     if check_contrast and is_low_contrast(arr):
#     128         warn('%s is a low contrast image' % fname)
# --> 129     if arr.dtype == bool:
#     130         warn('%s is a boolean image: setting True to 1 and False to 0' % fname)
#     131     return call_plugin('imsave', fname, arr, plugin=plugin, **plugin_args)
#
# AttributeError: 'Image' object has no attribute 'dtype'

# %%
# 1일차 전처리 연습
# 데이터 불러오기(양측 상악동 정상)
img1 = io.imread("exercise_0_0.png")
io.imshow(img1)
plt.show()

# %%
# (양측 상악동 mucosal thickening)
img2 = io.imread("exercise_1_1.png")
io.imshow(img2)
plt.show()

# %%
# (양측 상악동 air fluid)
img3 = io.imread("exercise_2_2.png")
io.imshow(img3)
plt.show()

# %%
# (우측 상악동 Haziness & 좌측 상악동 정상)
img4 = io.imread("exercise_3_0.png")
io.imshow(img4)
plt.show()

# %%
# 색상 모듈
from skimage import data, io, color

# %%
# Example Python Program for contrast stretching

from PIL import Image

 

# Method to process the red band of the image

def normalizeRed(intensity):

    iI      = intensity

   

    minI    = 86

    maxI    = 230

 

    minO    = 0

    maxO    = 255

 

    iO      = (iI-minI)*(((maxO-minO)/(maxI-minI))+minO)

    return iO

 

# Method to process the green band of the image

def normalizeGreen(intensity):

    iI      = intensity

   

    minI    = 90

    maxI    = 225

 

    minO    = 0

    maxO    = 255

 

    iO      = (iI-minI)*(((maxO-minO)/(maxI-minI))+minO)

    return iO

 

# Method to process the blue band of the image

def normalizeBlue(intensity):

    iI      = intensity

   

    minI    = 100

    maxI    = 210

 

    minO    = 0

    maxO    = 255

 

    iO      = (iI-minI)*(((maxO-minO)/(maxI-minI))+minO)

    return iO

 

 

# Create an image object

imageObject     = Image.open("exercise_0_0.png")

 

# Split the red, green and blue bands from the Image

multiBands      = imageObject.split()

 

# Apply point operations that does contrast stretching on each color band

normalizedRedBand      = multiBands[0].point(normalizeRed)

normalizedGreenBand    = multiBands[1].point(normalizeGreen)

normalizedBlueBand     = multiBands[2].point(normalizeBlue)

 

# Create a new image from the contrast stretched red, green and blue brands

normalizedImage = Image.merge("RGB", (normalizedRedBand, normalizedGreenBand, normalizedBlueBand))

 

# Display the image before contrast stretching

imageObject.show()

 

# Display the image after contrast stretching

normalizedImage.show()

# %%
# Create an image object

imageObject     = Image.open("exercise_0_0.png")

 

# Split the red, green and blue bands from the Image

multiBands      = imageObject.split()

 

# Apply point operations that does contrast stretching on each color band

normalizedRedBand      = multiBands[0].point(normalizeRed)

normalizedGreenBand    = multiBands[1].point(normalizeGreen)

normalizedBlueBand     = multiBands[2].point(normalizeBlue)

 

# Create a new image from the contrast stretched red, green and blue brands

normalizedImage = Image.merge("RGB", (normalizedRedBand, normalizedGreenBand, normalizedBlueBand))

 

# Display the image before contrast stretching

imageObject.show()

 

# Display the image after contrast stretching

normalizedImage.show()

# %%
# Create an image object

imageObject     = Image.open("exercise_2_2.png")

 

# Split the red, green and blue bands from the Image

multiBands      = imageObject.split()

 

# Apply point operations that does contrast stretching on each color band

normalizedRedBand      = multiBands[0].point(normalizeRed)

normalizedGreenBand    = multiBands[1].point(normalizeGreen)

normalizedBlueBand     = multiBands[2].point(normalizeBlue)

 

# Create a new image from the contrast stretched red, green and blue brands

normalizedImage = Image.merge("RGB", (normalizedRedBand, normalizedGreenBand, normalizedBlueBand))

 

# Display the image before contrast stretching

imageObject.show()

 

# Display the image after contrast stretching

normalizedImage.show()

# %%
# Create an image object

imageObject     = Image.open("exercise_3_0.png")

 

# Split the red, green and blue bands from the Image

multiBands      = imageObject.split()

 

# Apply point operations that does contrast stretching on each color band

normalizedRedBand      = multiBands[0].point(normalizeRed)

normalizedGreenBand    = multiBands[1].point(normalizeGreen)

normalizedBlueBand     = multiBands[2].point(normalizeBlue)

 

# Create a new image from the contrast stretched red, green and blue brands

normalizedImage = Image.merge("RGB", (normalizedRedBand, normalizedGreenBand, normalizedBlueBand))

 

# Display the image before contrast stretching

imageObject.show()

 

# Display the image after contrast stretching

normalizedImage.show()

# %%
# cv2.threshold() 함수 -> 5가지 기법 적용 코드
import numpy as np
# !pip install opencv-python

# %%
import cv2

# %%
img1 = cv2.imread('exercise_0_0.png', cv2.IMREAD_GRAYSCALE)

ret, thr1 = cv2.threshold(img1, 127, 255, cv2.THRESH_BINARY)
ret, thr2 = cv2.threshold(img1, 127, 255, cv2.THRESH_BINARY_INV)
ret, thr3 = cv2.threshold(img1, 127, 255, cv2.THRESH_TRUNC)
ret, thr4 = cv2.threshold(img1, 127, 255, cv2.THRESH_TOZERO)
ret, thr5 = cv2.threshold(img1, 127, 255, cv2.THRESH_TOZERO_INV)

cv2.imshow('original', img)
cv2.imshow('BINARY', thr1)
cv2.imshow('BINARY_INV', thr2)
cv2.imshow('TRUNC', thr3)
cv2.imshow('TOZERO', thr4)
cv2.imshow('TOZERO_INV', thr5)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2 = cv2.imread('exercise_1_1.png', cv2.IMREAD_GRAYSCALE)

ret, thr1 = cv2.threshold(img2, 127, 255, cv2.THRESH_BINARY)
ret, thr2 = cv2.threshold(img2, 127, 255, cv2.THRESH_BINARY_INV)
ret, thr3 = cv2.threshold(img2, 127, 255, cv2.THRESH_TRUNC)
ret, thr4 = cv2.threshold(img2, 127, 255, cv2.THRESH_TOZERO)
ret, thr5 = cv2.threshold(img2, 127, 255, cv2.THRESH_TOZERO_INV)

cv2.imshow('original', img2)
cv2.imshow('BINARY', thr1)
cv2.imshow('BINARY_INV', thr2)
cv2.imshow('TRUNC', thr3)
cv2.imshow('TOZERO', thr4)
cv2.imshow('TOZERO_INV', thr5)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2 = cv2.imread('exercise_2_2.png', cv2.IMREAD_GRAYSCALE)

ret, thr1 = cv2.threshold(img2, 127, 255, cv2.THRESH_BINARY)
ret, thr2 = cv2.threshold(img2, 127, 255, cv2.THRESH_BINARY_INV)
ret, thr3 = cv2.threshold(img2, 127, 255, cv2.THRESH_TRUNC)
ret, thr4 = cv2.threshold(img2, 127, 255, cv2.THRESH_TOZERO)
ret, thr5 = cv2.threshold(img2, 127, 255, cv2.THRESH_TOZERO_INV)

cv2.imshow('original', img2)
cv2.imshow('BINARY', thr1)
cv2.imshow('BINARY_INV', thr2)
cv2.imshow('TRUNC', thr3)
cv2.imshow('TOZERO', thr4)
cv2.imshow('TOZERO_INV', thr5)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2 = cv2.imread('exercise_3_0.png', cv2.IMREAD_GRAYSCALE)

ret, thr1 = cv2.threshold(img2, 127, 255, cv2.THRESH_BINARY)
ret, thr2 = cv2.threshold(img2, 127, 255, cv2.THRESH_BINARY_INV)
ret, thr3 = cv2.threshold(img2, 127, 255, cv2.THRESH_TRUNC)
ret, thr4 = cv2.threshold(img2, 127, 255, cv2.THRESH_TOZERO)
ret, thr5 = cv2.threshold(img2, 127, 255, cv2.THRESH_TOZERO_INV)

cv2.imshow('original', img2)
cv2.imshow('BINARY', thr1)
cv2.imshow('BINARY_INV', thr2)
cv2.imshow('TRUNC', thr3)
cv2.imshow('TOZERO', thr4)
cv2.imshow('TOZERO_INV', thr5)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 2일차 -> open cv 기법 중 Canny Edge Detection 적용 코드
import cv2

# %%
def canny() :
    img1 = cv2.imread('exercise_3_0.png', cv2.IMREAD_GRAYSCALE)
    
    edge1 = cv2.Canny(img1, 10, 70)
    edge2 = cv2.Canny(img1, 25, 100)
    edge3 = cv2.Canny(img1, 40, 70)
    
    cv2.imshow('original', img1)
    cv2.imshow('Canny Edge1', edge1)
    cv2.imshow('Canny Edge2', edge2)
    cv2.imshow('Canny Edge3', edge3)
    
    cv2.waitKey(0)
    cv. destroyAllWindows()
    
canny()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9c8f89ec5d53> in <module>
#      14     cv. destroyAllWindows()
#      15
# ---> 16 canny()
#
# <ipython-input-2-9c8f89ec5d53> in canny()
#      12
#      13     cv2.waitKey(0)
# ---> 14     cv. destroyAllWindows()
#      15
#      16 canny()
#
# NameError: name 'cv' is not defined

# %%
def canny() :
    img2 = cv2.imread('exercise_1_1.png', cv2.IMREAD_GRAYSCALE)
    
    edge1 = cv2.Canny(img2, 50, 200)
    edge2 = cv2.Canny(img2, 100, 200)
    edge3 = cv2.Canny(img2, 170, 200)
    
    cv2.imshow('original', img2)
    cv2.imshow('Canny Edge1', edge1 )
    cv2.imshow('Canny Edge2', edge2)
    cv2.imshow('Canny Edge3', edge3)
    
    cv2.waitKey(0)
    cv2. destroyAllWindows()
    
canny()

# %%
# image data normalization (Contrast Normalization 관련)

from skimage import io
from matplotlib import pyplot as plt

import numpy as np


img = io.imread("exercise_0_0.png")
img = (img - np.min(img)) / (np.max(img)-np.min(img))

plt.imshow(img)

# %%
img = io.imread("exercise_2_2.png")
img = (img - np.min(img)) / (np.max(img)-np.min(img))

plt.imshow(img)

# %%
img = io.imread("exercise_1_1.png")
img = (img - np.min(img)) / (np.max(img)-np.min(img))

plt.imshow(img)

# %%
# 사진 간 contrast 정규화 다시 조사
import argparse
import os

# %%
# load data
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# train
from torch import nn
from torch.nn import functional as F

# visualization
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-0c2e1c4c4b27> in <module>
#       1 # load data
# ----> 2 import torch
#       3 from torch.utils.data import DataLoader
#       4 from torchvision import datasets, transforms
#       5
#
# ModuleNotFoundError: No module named 'torch'

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([

      #  ContrastBrightness(1.2,25),

        transforms.Normalize([0.5],
                             [0.25])
    ]),
    'test': transforms.Compose([
 
       # ContrastBrightness(1.2,25),
        transforms.Normalize([0.5],
                             [0.25])
    ]),
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e54b6062446b> in <module>
#       2 # Just normalization for validation
#       3 data_transforms = {
# ----> 4     'train': transforms.Compose([
#       5
#       6       #  ContrastBrightness(1.2,25),
#
# NameError: name 'transforms' is not defined

# %%
# normalize 테스트
img1 = cv2.imread("exercise_0_0.png", cv2.IMREAD_GRAYSCALE)

# %%
img2 = cv2.imread("exercise_1_1.png", cv2.IMREAD_GRAYSCALE)

# %%
img3 = cv2.imread("exercise_2_2.png", cv2.IMREAD_GRAYSCALE)

# %%
img4 = cv2.imread("exercise_3_0.png", cv2.IMREAD_GRAYSCALE)

# %%
print(img1.shape)
print(img2.shape)
print(img3.shape)
print(img4.shape)
# Out:
# (444, 436)
# (440, 470)
# (432, 450)
# (448, 450)

# %%
img11= cv2.resize(img1, (300,300), interpolation=cv2.INTER_AREA)

# %%
img22= cv2.resize(img2, (300,300), interpolation=cv2.INTER_AREA)

# %%
img33= cv2.resize(img3, (300,300), interpolation=cv2.INTER_AREA)

# %%
img44= cv2.resize(img4, (300,300), interpolation=cv2.INTER_AREA)

# %%
import numpy as np 
abc = [] 

abc.append(img1.flatten())
abc.append(img2.flatten())
abc.append(img3.flatten())
abc.append(img4.flatten())

# %%
concat = np.concatenate(abc)/255
concat.mean(), concat.std(), concat.max(), concat.min()
# Out:
# (0.5679713530648729, 0.31619194449911736, 1.0, 0.0)

# %%
tranferNormalize([img.mean()], [img.std()])

# %%
mean(img1, img2, img3, img4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9e12c8bf924e> in <module>
# ----> 1 mean(img1, img2, img3, img4)
#
# NameError: name 'mean' is not defined

# %%
np.random.randn(30,600,600,1).mean()
# Out:
# -0.00031695987962690887
