# %% [markdown]
# <a href="https://colab.research.google.com/github/sallyy1/data/blob/sallyy1-patch-1/%ED%83%80%EC%9D%B4%ED%83%80%EB%8B%89(1)%20/%20titanic_tutorial_for_beginners_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titanic Challenge

# %% [markdown]
# 이 튜토리얼은 캐글에 처음 도전하는 분들을 위한 것입니다. 커널부문 세계1위인 안드레이 룩야넨코의 노트북에 한글로설명을 추가로 붙인 것입니다.
# 이 노트의 결과는 작성 현재 Top 4% 결과를 보입니다. (랜덤이 되는 부분이 있어서 결과가 약간씩 다르게 나오긴 합니다만 여러번 하시면 4% 선까지 올라갑니다.)
# Kaggle에 처음으로 로그인하는 것은 쉬운 결정이 아닙니다. 내가 무슨 머신러닝을? 이런 생각을 하실 수 도 있겠습니다.
# 캐글은 대회로서도 의미가 있겠으나 배움의 터입니다. 이런 데이터를 초보자가 어디서 구하며 어떻게 다른 사람들이 일한 것을 통해 이리 쉽게 배우겠습니까?
# 이 튜토리얼이 끝날 때 즈음에는 Kaggle의 온라인 코딩 환경을 사용하는 방법에 대한 이해를 얻게되며 그 와중에 머신러닝 학습 모델을 학습하게됩니다.
#
# 우측 상단에 Copy & Edit을 눌러서 복사.

# %% [markdown]
# ![](https://i.imgur.com/rRFchA8.png)

# %% [markdown]
# <a id = "table_of_contents"></a>
# ## Table of contents
#
# [Part 1: 데이터 준비 및 모듈 임포트](#part1)
# [Part 2: 파일 병합](#part2)
# [Part 3: 파일 탐색](#part3)
# [Part 4: 데이터 탐구 (Exploratory Data Analysis)](#part4)
# [Part 5: Feature Engineering](#part5)
#
# [Part 6: 마지막 항목 결정](#part6)
# [Part 7: 머신러닝 모델 만들기](#part7)
# [Part 8: 중요도에 따라 모델 재 설정 ](#part8)
# [Part 9: 하이퍼 파라미터 튜닝](#part9)
# [Part 10: 모델 재 트레이닝](#part10)
#
# [Part 11: 마지막 보팅](#part11)
# [Part 12: 마지막 모델 예측](#part12)
# [Part 13: 제출](#part13)

# %% [markdown]
# <a id = "part1"></a>
# ## Part 1: 데이터 준비 및 모듈 임포트
# [Go to the Table of Contents](#table_of_contents)

# %%
# 기본 데이터 정리 및 처리
import numpy as np
import pandas as pd

# 시각화
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno ## 누락된 값을 한눈에 볼 수 있게 함

# 전처리 및 머신 러닝 알고리즘
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier

# 모델 튜닝 및 평가
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict
from sklearn import model_selection

# 경고 제거 (판다스가 에러 메세지를 자주 만들어 내기 때문에 이를 일단 무시하도록 설정합니다.)
import sys
import warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 중요 링크
#
# [구글 콜랩](https://colab.research.google.com/)
#
# [깃헙브](https://github.com)
#
# ### 초보자이실 경우는 아래 링크 중 본인에게 맞는 것을 미리 공부해 보는 것도 도움이 됩니다.
#
# [edx의 파이썬 기초수업](https://learn.edx.org/topic-python/?g_acctid=926-195-8061&g_campaign=gs-nonbrand-topic-python&g_campaignid=1535528542&g_adgroupid=58645176415&g_adid=405031374941&g_keyword=learn%20python%20online%20tutorial&g_keywordid=kwd-357260176984&g_network=g?utm_source=adwords&utm_campaign=1535528542&utm_medium=58645176415&utm_term=learn%20python%20online%20tutorial&gclid=CjwKCAjwwYP2BRBGEiwAkoBpAu6FTNidm90CEM1AJQGDn_mvW_bDMJSkWuWk6DnUJCrCXnG0-vW_aBoC8GwQAvD_BwE)
#
# [파이썬 org에 나오는 파이썬 기초수업](https://docs.python.org/3/tutorial/)
#
# [w3schools 파이썬 기초수업](https://www.w3schools.com/python/)
#
# [Joshua Choi님의 파이썬 기초 문법 연습](https://joshua-mobile-choi-1756.trinket.io/python-3-4#/tasks/task-1-print-statement)
#
# [Joshua Choi님의 타이타닉 판다스 101 사용 예](https://www.kaggle.com/joshuajhchoi/101-pandas-tips-for-beginners-titanic-en-kr)
#
# [Joshua Choi님의 타이타닉 시각화 101 사용 예](https://www.kaggle.com/joshuajhchoi/101-data-visualization-tips-for-titanic-beginners)
#
# [Seaborn연습](https://seaborn.pydata.org/tutorial/aesthetics.html)

# %% [markdown]
# ### CSV to DF
#
# * csv를 임포트하여 데이터셋이 판다스 데이터프레임이 되도록 합니다.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-73dbf61a-9a50-4678-ba59-f391765a7cba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73dbf61a-9a50-4678-ba59-f391765a7cba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train (1).csv
# Saving test.csv to test (1).csv

# %%
import io
test = pd.read_csv(io.BytesIO(uploaded['test.csv']))
train = pd.read_csv(io.BytesIO(uploaded['train.csv']))

# %%
 # 이 것이 처음하는 사람에게 예상보다 어려울 수 있는데 복사한 것에서 데이터가 전달이 잘 안 되었다면 "+Add Data" 누르시고 'Competition Data'에서 "Titanic Data" 불러온 후 파일을 찍어서 경로 주소 확인해야 함 
test = pd.read_csv('../input/titanic/test.csv')
train = pd.read_csv('../input/titanic/train.csv')

# 이제 csv file들 (test & train)은 데이터 프레임이 되었습니다.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-77-e8d31a85efe0> in <module>()
#       1 # 이 것이 처음하는 사람에게 예상보다 어려울 수 있는데 복사한 것에서 데이터가 전달이 잘 안 되었다면 "+Add Data" 누르시고 'Competition Data'에서 "Titanic Data" 불러온 후 파일을 찍어서 경로 주소 확인해야 함
# ----> 2 test = pd.read_csv('../input/titanic/test.csv')
#       3 train = pd.read_csv('../input/titanic/train.csv')
#       4
#       5 # 이제 csv file들 (test & train)은 데이터 프레임이 되었습니다.
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/titanic/test.csv'

# %% [markdown]
# 구글 콜랩에서 사용하실 때는 컴퓨터에 파일을 다운로드 한 후 아래 코드를 입력하면 불러올 수 있게 됩니다.
#
#
#     #+) import pandas as pd
#     # 주의할 점은 pandas를 혹시 import 안 한 상태면 반드시 해야함.
#     from google.colab import files
#     uploaded = files.upload()
#
# 그런 다음 아래 코드를 통해서 csv를 데이터프레임으로 바꿀 수 있게 됩니다.
#
#     import io
#     test = pd.read_csv(io.BytesIO(uploaded['test.csv']))
#     train = pd.read_csv(io.BytesIO(uploaded['train.csv']))

# %% [markdown]
# ### 데이터프레임을 보는 다양한 방법

# %% [markdown]
# `head()`첫 5행을 볼 수 있습니다.

# %%
train.head(n=3)

# %%
# head 빼면?
train

# %% [markdown]
# `tail()` 마지막 5행을 볼 수 있습니다.

# %%
train.tail()

# %% [markdown]
# `describe()` 각 열의 통계적인 면을 보여 줍니다.
#
# 기본은 연속된 값을 가진 열만 보여주나 `include='all'로 세팅하면 모두 볼 수 있습니다.

# %%
train.describe(include='all') # include='all' 옵션
                              # -> 연속형 변수가 아닌 Name, Sex, Ticket, Cabin, Embarked의 결과까지 모든항목에 대한 정보를 보여줌

# %%
train.describe()

# %%
# ()를 빼보면?
train.describe  # -> 통계 값이 아니라 한줄한줄 나온다

# %% [markdown]
# `dtypes` 모든 열의 데이터 종류를 보여 줍니다.

# %%
train.dtypes

# %% [markdown]
# `info()` 는 `dtypes` 의 좀  더 발전된 개념으로 데이터 타입뿐만 아니라 빈칸이 아닌 갯수까지 보여 줍니다.
#
# [describe 학습](https://www.w3resource.com/pandas/dataframe/dataframe-describe.php)

# %%
# dtypes 에 괄호를 넣으면?
train.dtypes()

# %%
# dtype은 series라서 불러 올 수 없어서 error가 나온다. 즉 ()를 넣는다는 것은, 각 행들의 값들이 있어야 하는데, 
#dtype은 그런 것이 아니므로 call을 할 수가 없다. 아래의 column 값은 것도 call을 할 수 없는데 이는 인덱스의 역할을 하는 것이지 각 행별로 값을 가진 것이 아니라서 역시 error가 나올 수 밖에 없다.

# %%
train.info() # 빈칸이 아닌 갯수(= <not null> 의 갯수까지 보여줌)

# %% [markdown]
# `columns`은 데이터 프레임의 열의 제목들을 보여 줍니다.

# %%
train.columns # 열이 우리가 다루어야 할 항목들.

# %%
# 항목을 파이썬 리스트처럼 슬라이싱으로 인덱싱 할 수 있음

# %% [markdown]
# 단순히 연습으로, 한 번 원하는 컬럼만 인덱싱해 보겠습니다.
#
# 인덱싱에 대해 더 공부하고 싶으시다면 아래 링크를 클릭하여 공부해 보세요.
#
# [w3schools 넘파이 어레이 인덱싱](https://www.w3schools.com/python/numpy_array_indexing.asp)
#
# [Joshua CHoi님의 파이썬 인덱싱](https://joshua-mobile-choi-1756.trinket.io/python-3-4#/tasks/task-4-string-indexing)
#
# [Joshua Choi님의 파이썬 리스트 인덱싱](https://joshua-mobile-choi-1756.trinket.io/python-3-4#/tasks/task-15-list-methods)

# %%
train.columns[3], train.columns[3:5]
# 주의할 점은 파이썬은 처음 아이템이 0부터 시작하므로 [3]을 인덱싱하면 실제로는 4번째 것을 인덱싱하는 것이다.
# [3:5]는 4번째 것[3]부터 여섯번 째 것[5] 이전을 의미한다. 따라서 이 경우에는 4번째, 5번째 것을 인덱싱하게 된다.

# %% [markdown]
# 한 행 뿐만 아니라 여러행을 인덱싱 할 수도 있습니다.

# %%
train[5:20]

# %% [markdown]
# `shape` 은 행의 갯수와 열의 갯수를 보여 줍니다

# %%
train.shape

# %% [markdown]
# <a id = "part2"></a>
# ## Part 2:  파일 병합
# [Go to the Table of Contents](#table_of_contents)
#
# * ntrain과 ntest의 shape을 확보해놓습니다. (병합 한 것을 나중에 다시 갈라 놓기 위한 준비)
# * y_train은 알려진 결과 값이니 따로 모셔 놓고
# * 테스트의 승객 아이디는 나중에 최종 결과에 넣을 것이기 때문에 따로 떼어 놓습니다.
# * train과 test를 병합하여 data 란 파일을 만듭니다. 문자로 된 것을 숫자로 바꾼다든가. 숫자를 인터발 별로 그룹화 한다든가 할 때 한꺼번에 하기 위해 합해 놓습니다.

# %%
# 병합 준비
ntrain = train.shape[0]           # shape 대괄호 안에 0을 추가하면, 첫 번째 열의 shqpe를 얻을 수 있음.
ntest = test.shape[0]       ## 단, 합치기 전에 훈련데이터의 길이(ntrain)과 테스트데이터의 길이(ntest)를 저장해 놓는다.
                            ## -> 나중에 적용하면 합친 것에서 나누기 위한 준비
# 아래는 따로 잘 모셔 둡니다.
y_train = train['Survived'].values # 훈련 데이터에 대해 Survived 열 값을 저장함(이는 0또는 1이어야 함)
passId = test['PassengerId']       # 테스트셋의 경우 Survived 값이 모두 빈 값(내가 마지막에 예측해야 함)

# 병함 파일 만들기
data = pd.concat((train, test)) ## concat이란 함수를 사용하여, 2개의 데이터프레임을 연결
                                ## ->문자열을 숫자로 변환하거나 간격을 기준으로 그룹화 할 때 이렇게 묶어 한 번에 모두 수행하는 것이 더 쉬움.
# 데이터 행과 열의 크기는
print("data size is: {}".format(data.shape))

# %%
# ntrain 이 어떻게 생겼나 볼까요?
ntrain

# %%
# ntest 는?
ntest

# %%
y_train

# %%
passId

# %%
# train과 test를 합친 data를 볼까요?
# test에서 "Survived"는 빈칸을 나타내는 NaN (Not a Number) 을 보여줍니다.

data

# %%
# format을 간단히 연습합니다.
print("I like {}".format('eggs'))

# %%
print("I like {0} and {1}".format('eggs', 'spam'))

# %%
print("I like {1} and {0}".format('eggs', 'spam'))

# %% [markdown]
# #### 파이썬의 프린트문과 포맷에 대해 보시려면 아래 링크를 클릭하세요.
#
# [프린트문](https://joshua-mobile-choi-1756.trinket.io/python-3-4#/tasks/task-1-print-statement)
#
# [포맷팅](https://joshua-mobile-choi-1756.trinket.io/python-3-4#/tasks/task-11-string-format)

# %%
train['Survived'].value_counts() # value_counts() 함수 -> 열의 고유 값을 반환해주는 함수. 각 고유 값을 찾아서 고유값이 몇 개 있는지 카운트 해줌.

# %% [markdown]
# 트레인 데이터에 있는 인원 중 342명이 살아남고 549명이 사망했다는 것을 볼 수 있습니다.

# %%
train['Sex'].value_counts()

# %% [markdown]
# <a id = "part3"></a>
# ## Part 3: 파일 탐색
# [Go to the Table of Contents](#table_of_contents)

# %%
missingno.matrix(data, figsize = (15,8)) # missingno ->빈 값 데이터를 쉽게 시각화
            #matrix() 코맨드 -> 행렬 형식으로 빈 값 데이터를 시각화하는 명령

# 흰 색이 빈 값을 나타냄
# 가장 오른쪽 한 줄은 '스파크라인' -> 각 행의 데이터의 완전성을 나타냄.

# %%
missingno.matrix(data, figsize = (6,4))  # 크기 작게 가능

# %% [markdown]
# 위 도표는 빈 값을 직관적으로 볼 수 있게 합니다.
# 아래 쪽 `Survived`가 비어 있는데 이 것은 테스트에 우리가 답으로 예측해야 하는 부분이라서 그렇 습니다.

# %%
data.isnull().sum() # 비어 있는 값들을 체크해 본다.
                    # 'isnull().sum()' 함수 <- null의 개수 확인

# %%
data.isna().any().any()

# %%
data.isna().any()

# %%
# data.isnull.any() -전체에 빈 값이 있나 없나? ='isna()'를 써도 결과 같음 // 각 항목 별로 알려줌
# data.isnull.sum() - 전체 각 항목 중 빈칸이 몇 개나 있나?              // 각 항목 별로 알려줌
# data.isnull.any().any() -전체 중 빈칸이 있나 없나?            // 전체 True/False

# %%
data.Age.isnull().any() # null이 하나라도 있는지 검사
        # cf) isnull().all() -> 데이터가 모두 null 인지 검사

# %% [markdown]
# 열 이름을 보겠습니다.

# %% [markdown]
# [Kaggle 페이지에서 타이타닉 열 이름 보기 (해당 페이지 중간에 Dictionary 보시면 됨)](https://www.kaggle.com/c/titanic/data)

# %%
data.columns

# %% [markdown]
# ### Features 항목
#
# #### 항목의 종류
#
# * 범주형 항목 (Categorical Features)
#
# 범주형 항목은 법주형 변수로 된 항목으로 범주형 변수는 둘 이상의 결과 요소가 있는 변수이며 해당 기능의 각 값을 범주별로 분류 할 수 있습니다.
#
# 예를 들어 성별은 두 가지 범주 (남성과 여성)의 범주 형 변수입니다.
#
# 이산형 변수(discrete variable) = 범주형 변수 (categorical variable) 의 하나로 명목 변수 norminal variable 라고도합니다.
#
# 데이터 셋에서 명목 항목 : Sex, Embark 이며 우리는 Name, Ticket 등을 이로 변환해야 할 것 같습니다.
#
#
# * Ordinal Variable :
#
# 순위 변수는 범주 형의 하나지만 그 차이점은 값 사이의 상대 순서(=서열) 또는 정렬이 가능하다는 것입니다.
#
# 데이터 셋에서 순위 항목 : PClass 이며 우리는 Cabin을 이 범주로 변환해서 사용해야 할 것 같습니다.
#
#
# * 연속형 항목 (Continuous Features):
#
# 서로 연속된 값을 가진 변수를 가진 항목이며 여기에서 우리는 연령을 대표적인 것으로 볼 수 있습니다.
#
# Age, SipSp, Parch, Fare는 interval variable로 만들어 이에 적용해야 할 것 같습니다.
#
#
#
# * 아래의 항목에서 열의 이름을 볼 수 있습니다.
#
#           Variable          정의                Key
#
#           survival          생존 여부            0 = No, 1 = Yes
#
#           pclass            선실 등급            1 = 1st, 2 = 2nd, 3 = 3rd
#
#           sex               성별
#
#           Age               나이
#
#           sibsp             형재 자매의 수/ 배우자 등이 승선한 경우 수
#
#           parch             부모나 자식과 같이 탄 경우 수
#
#           ticket            표 번호
#
#           fare              요금
#
#           cabin             선실 번호
#
#           embarked          승선한 항구         C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# <a id = "part4"></a>
# ## Part 4: 데이터 탐구 (Exploratory Data Analysis)
# [Go to the Table of Contents](#table_of_contents)
#
# * train파일 순서대로 데이터 파일의 열들을 봅니다.

# %%
train.head()

# %% [markdown]
# * 파일 각 열의 상관 관계를 보겠습니다.
#
# Co-relation 매트릭스는 seaborn에서 변수 간 상관 계수를 보여주는 표입니다. 표의 각 셀은 두 변수 간의 상관 관계를 보여줍니다. 상관 매트릭스는 고급 분석에 대한 입력 및 고급 분석에 대한 진단으로 데이터를 요약하는 데 사용됩니다.
#
# 참고: https://seaborn.pydata.org/examples/many_pairwise_correlations.html
#
# 아래 마스크 셋업은 0로 행렬을 상관 행렬과 같은 모양으로 만든 후 여기에 불리안 값을 넣고 이를 다시 True만 만듭니다.
#
# triu 는 우측 상단 삼각행렬을 의미
#
# annot= True는 각 셀에 숫자를 표시하라는 것이고, False는 하지 말라는 것이구요
#
# 이어서 이를 heatmap으로 런칭합니다.

# %%
# Co-relation 매트릭스 <-seaborn 라이브러리
corr = data.corr()
# 마스크 셋업
mask = np.zeros_like(corr, dtype=np.bool) # 0으로 되어있는 코-릴레이션 매트릭스로 만들기 위한 설정 -> 그런 다음 불리안 값을 넣고 True로 만든다?
mask[np.triu_indices_from(mask)] = True   # triu 는 오른쪽 삼각형을 의미
# 그래프 셋업
plt.figure(figsize=(14, 8))
# 그래프 타이틀
plt.title('Overall Correlation of Titanic Features', fontsize=18)
#  Co-relation 매트릭스 런칭
sns.heatmap(corr, mask=mask, annot=False,cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
plt.show()
                            # annot 옵션은 각 셀에 숫자를 표시할 지/안 할지 (True/False)

# %%
# Co-relation 매트릭스
corr = data.corr()
print(corr)

# %%
# Co-relation 매트릭스
corr = data.corr()
# 변수 corr 에 data 데이터셋에 콜리레이션을 만드는 함수를 ( .corr()) 붙인 것을 넣었습니다.

# 마스크 셋업
mask = np.zeros_like(corr, dtype=np.bool)
# 여기에 0으로 된 매트릭스를 마스크에 붙입니다. 모양을 만드는 것이지요
print(mask)

# %%
# Co-relation 매트릭스
corr = data.corr()

# 앞에 보시면 corr에서 관계 숫자는 만들어졌고 mask는 같은 모양의 매트릭스는 만들었는데 모두 0이 아니니 False로 뜨지요?
mask[np.triu_indices_from(mask)] = True

# 그래프 셋업
plt.figure(figsize=(7,4))   # figsize 보다 작게

# 그래프를 그릴 그림판을 만드는 것입니다

# 그래프 타이틀
plt.title('Overall Correlation of Titaninc Features', fontsize=18)

# 타이틀도 넣으니 뭔가 만들어졌지요

# %%
#  Co-relation 매트릭스 런칭
sns.heatmap(corr, mask=mask, annot=False,cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
plt.show()

# %% [markdown]
# * [히트맵](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
#
# * [판다스 코릴레이션 매트릭스](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)
#
# * [씨본 콜릴레이션 히트맵](https://seaborn.pydata.org/generated/seaborn.heatmap.html)

# %% [markdown]
# * "Surived" 분석
#
# 한 열씩 검토해 보겠습니다.
#
# Survived - Key: (0 - Not Survived, 1- Survived)
#
# Survived는 숫자로 값을 주지만 Categorical Variable인 셈입니다.
#
# 죽던지 살던지 둘 중 하나의 값을 줍니다.
#
# countplot을 그려 봅니다.
#
# 사이즈는 가로 10인치 세로 2인치
#
# 생존 여부 0과 1의 숫자를 세어 본 후 그림을 그리도록 명령을 하는 것입니다.
#
# pyplot(plt)의 figure라는 메소드를 써서 그림판의 크기를 정하고, seaborn의 카운트플롯을 그리라는 것입니다.

# %%
fig = plt.figure(figsize=(10,2))
sns.countplot(y='Survived', data=train)
print(train.Survived.value_counts())  #y축 기준으로 사망(0)인지 / 생존(1)인지 count하는 그래프 시각화해봄

# %% [markdown]
# * 불행히도 사망자가 훨씬 많아 보입니다.
# * 전체 사망자 비율을 좀 보겠습니다.
#
# * 파이그래프랑 카운트 플롯을 서브플롯으로 그립니다.
# * 행은 하나 열은 2개의 서브 플롯입니다. 사이즈는 가로 15인치 세로 6인치
# * 'Survived'의 값을 카운트해서 파이플롯을 만듭니다.
# * explode는 폭발하는 것이니까 1이면 튀어 나가는 것인데 0을 주면 분리만 되고 돌출은 되지 않습니다. 이어서 0, 1인 것은 첫 번째 것은 아니고 두번 째 것은 분리된다는 의미로 생각하시면 됩니다.
# * autopercent는 1.1이 표현하는 부분은 소수점 한 자리까지 보여 주라는 의미입니다. 뒤에 점 이하가 4면 둘 다 소수점 4자리수 까지 보여 줍니다.
# * ax[0]은 첫번째 칸입니다.
# * set_title 메소드는 서브 플롯의 제목을 보여 줍니다.

# %%
f,ax=plt.subplots(1, 2, figsize=(15, 6))
train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('Survived',data=train, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
f,ax=plt.subplots(1, 2, figsize=(15, 6))
train['Survived'].value_counts().plot.pie(explode=[0, 0.0], autopct='%1.1f%%', ax=ax[0], shadow=True) # 0으로 변경해봄 ->파이차트 분리 없음
ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('Survived',data=train, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# * 위의 것을 아래와 같이 함수로 만들겠습니다. (물론 자주 쓰이지는 않겠지만 연습이니)

# %%
def piecount(col):      # 함수를 만들 때 열 값을 불러오는데 그 중 Survived 값을 마지막에 호출
    f, ax = plt.subplots(1, 2, figsize=(15, 6))
    train[col].value_counts().plot.pie(explode=[0.1 for i in range(train[col].nunique())], autopct='%1.1f%%', ax=ax[0], shadow=True) # (explode 옵션) 1이면 파이차트 분리, 0이면 분리 없음
                                                                                                                                     # (autopct 옵션) 앞자리 1자리 이상, 소수점 이하 1자리
    ax[0].set_title(col)  # ax[0] 은 서브플롯에서 좌측 첫 그래프를 의미함(여기선 파이차트) && 'set_title 메소드'는 서브플롯의 제목을 표시함.
    ax[0].set_ylabel('')
    sns.countplot(col, data=train, ax=ax[1])
    ax[1].set_title(col)
    plt.show()            # show 메소드는 pyplot을 보여줌.

piecount('Survived')

# %%
# (연습) x의 세제곱을 구하는 함수

y = input()
x = int(y)

def mycal(x):
  print(x**3)

mycal(x)

# %% [markdown]
# [함수 만들기 공부](https://trinket.io/joshua-mobile-choi-1756/courses/python-3-4#/tasks/task-20-making-functions)
#
# [파라미터와 아규먼트 공부](https://trinket.io/joshua-mobile-choi-1756/courses/python-3-4#/tasks/task-21-parameters-and-arguments)
#
# * "Pclass" 분석
#
# * Pclass는 값이 숫자이나 서열이 정해진 Ordinal Feature이다.
# * Key:1 = 1st, 2= 2nd, 3 = 3rd
# * 각 클래스 당 생존자를 보겠습니다.

# %%
# groupby 메소드
train.groupby(['Pclass','Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
# crosstab 메소드
pd.crosstab(train.Pclass, train.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row0_col0,#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row1_col1,#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row3_col0,#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row3_col1,#T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_d3966f3c_0efd_11eb_97fb_0242ac1c0002row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# * 1등급 객실의 사람들은 생존자가 더 많고, 2등급은 생존자에 비해 사망자가 조금 더 많으나, 3등급은 사망자가 3배 이상 많다는 것을 알 수 있습니다.

# %%
# (연습)
train.groupby(['Survived','Pclass'])['Pclass'].count()
# Out:
# Survived  Pclass
# 0         1          80
#           2          97
#           3         372
# 1         1         136
#           2          87
#           3         119
# Name: Pclass, dtype: int64

# %%
# subplot 2칸에 2개의 다른 막대그래프 넣기

#f->도형만들기 && ax->그래프크기
f, ax = plt.subplots(1, 2, figsize=(12, 6)) #plt.subplot ->파이 플롯에서 서브플롯으로 만들어라.
train[['Pclass','Survived']].groupby(['Pclass']).mean().plot.bar(ax=ax[0])  #이번에는 평균(mean) 내라 && ax[0]-> 처음그래프
ax[0].set_title('Survived per Pcalss')      # 첫 그래프 제목 넣기
sns.countplot('Pclass', hue='Survived', data=train, ax=ax[1]) # 두 번째 그래프에는 앞에서와 같이 숫자의 합을 카운트플롯에 넣기
ax[1].set_title('Pcalss Survived vs Not Survived') # 두번재 그래프 제목 넣기
plt.show()  #그래프 보여주라는 명령

# %% [markdown]
# * 위에 만든 함수를 한 번 써 먹어 볼까요?

# %%
piecount("Pclass")

# %% [markdown]
# * %는 3등칸이 반이 넘으나 위의 그래프에서 생존자는 1등석이 가장 많다는 것을 알 수 있습니다.
# * 각 클래스 당 생존률을 볼까요?

# %% [markdown]
# ### "Name" 분석
# * 이름은 거의 모두 다를 가능성이 큽니다. Family Name, First Name, Middle Name and even Dr. Capt, master and so on 모두 감안하면...
# * 분류를 한 번 해 봅니다.
# * 리스트를 한 번 주 욱 보겠습니다.

# %%
data.Name.value_counts()
# Out:
# Kelly, Mr. James                                2
# Connolly, Miss. Kate                            2
# Leitch, Miss. Jessie Wills                      1
# Brandeis, Mr. Emil                              1
# Turcin, Mr. Stjepan                             1
#                                                ..
# Rice, Master. Eugene                            1
# Widener, Mrs. George Dunton (Eleanor Elkins)    1
# Balkic, Mr. Cerin                               1
# Celotti, Mr. Francesco                          1
# Abelseth, Miss. Karen Marie                     1
# Name: Name, Length: 1307, dtype: int64

# %% [markdown]
# * 이름은 언뜻 보아서 감이 안 옵니다. 중간에 있는 Mr. 같은 호칭을 볼까요.
# * ['Initial']이란 열을 새로 만들어서 여기에 Name에서 추출한 Regular Expression을 넣습니다.
# * 아래에서 str.extract('([A-Za-z]+).')부분은 str에서 대문자 A~Z, 소문자 a~z 중에 . 명령을 통해 .으로 끝나는 부분을 추출해 내는 것입니다.
# * ('^([A-Za-z]+)')으로 하면 처음에 나오는 문자 덩어리가 될 것이고 +를 빼면 첫 스펠링 한캐릭터만 추출합니다.

# %% [markdown]
# [Regex 공부](https://en.wikipedia.org/wiki/Regular_expression)
#
# * 안전을 위해 카피를 하나 만들어서 새로운 항목을 만들어 봅니다.

# %%
# 복사본을 만들어 'Initial'이란 열을 새로 만든다.
temp = data.copy()
temp['Initial'] = 0
temp['Initial'] = data.Name.str.extract('([A-Za-z]+)\.') # +-> 문자덩어리로 나오게 하는 옵션  && \. ->마침표로 끝나는 것을 추출해라
#+를 포함하면 'Mr' 가 나올 것이며, +를 빼면 첫 스펠링 한 글자인 'M'만 나올 것임

# %%
# (연습)
data.Name.str.extract('([A-Za-z0-9]+)')
# Out:
#              0
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# ..         ...
# 413    Spector
# 414      Oliva
# 415    Saether
# 416       Ware
# 417      Peter
#
# [1309 rows x 1 columns]

# %% [markdown]
# Miss나 Mr등은 많으나 익숙하지 않은 몇 개가 보입니다.

# %%
temp['Initial'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Ms            2
# Mlle          2
# Major         2
# Don           1
# Capt          1
# Mme           1
# Dona          1
# Countess      1
# Sir           1
# Jonkheer      1
# Lady          1
# Name: Initial, dtype: int64

# %% [markdown]
# 이를 성별로 봅니다.

# %%
pd.crosstab(temp.Initial, temp.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col0,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col1,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col3,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col5,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col6,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col8,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col9,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col13,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col16,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col17,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col2,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col4,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col7,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col10,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col11,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col12,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col14,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col15{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col2,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col4,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col7,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col10,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col11,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col12,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col14,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col15,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col0,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col1,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col3,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col5,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col6,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col8,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col9,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col13,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col16,#T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col17{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dona</th>        <th class="col_heading level0 col5" >Dr</th>        <th class="col_heading level0 col6" >Jonkheer</th>        <th class="col_heading level0 col7" >Lady</th>        <th class="col_heading level0 col8" >Major</th>        <th class="col_heading level0 col9" >Master</th>        <th class="col_heading level0 col10" >Miss</th>        <th class="col_heading level0 col11" >Mlle</th>        <th class="col_heading level0 col12" >Mme</th>        <th class="col_heading level0 col13" >Mr</th>        <th class="col_heading level0 col14" >Mrs</th>        <th class="col_heading level0 col15" >Ms</th>        <th class="col_heading level0 col16" >Rev</th>        <th class="col_heading level0 col17" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col10" class="data row0 col10" >260</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col11" class="data row0 col11" >2</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col12" class="data row0 col12" >1</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col13" class="data row0 col13" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col14" class="data row0 col14" >197</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col15" class="data row0 col15" >2</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col16" class="data row0 col16" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row0_col17" class="data row0 col17" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col1" class="data row1 col1" >4</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col5" class="data row1 col5" >7</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col8" class="data row1 col8" >2</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col9" class="data row1 col9" >61</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col13" class="data row1 col13" >757</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col15" class="data row1 col15" >0</td>
#                         <td id="T_dcedd7b4_0efd_11eb_97fb_0242ac1c0002row1_col16" class="data row1 col16" >8</td>

# %% [markdown]
# * 생존률로 봅니다.
#
# * 생존율 함수를 만들어 보겠습니다.

# %%
# 생존율 함수 만들기 (기능: 특정 열(col)에 대해 생존('Survived')율(mean) -즉, 0이냐 1이냐의 평균 값을 열 별로 내는 것을 return 함.)
def survpct(col):
    return temp.groupby(col)['Survived'].mean()

survpct('Initial')
# Out:
# Initial
# Capt        0.000000
# Col         0.500000
# Countess    1.000000
# Don         0.000000
# Dona             NaN
# Dr          0.428571
# Jonkheer    0.000000
# Lady        1.000000
# Major       0.500000
# Master      0.575000
# Miss        0.697802
# Mlle        1.000000
# Mme         1.000000
# Mr          0.156673
# Mrs         0.792000
# Ms          1.000000
# Rev         0.000000
# Sir         1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# * 생존 숫자로 봅니다.

# %% [markdown]
# * test 에 있는 Dona의 나이를 보고 어디에 넣을지 보겠습니다.
# * Ms. 는 현대처럼 Miss + Mrs를 합친 말이 아니라 당시에는 귀족미망인을 의미하는 것이 었습니다. Mlle나 Mme등도 마드모아젤과 마담의 줄인말일 경우일 것입니다. 귀족 여성들로 보아야겠죠.

# %%
temp['LastName'] = data.Name.str.extract('([A-Za-z]+)')

# %%
pd.crosstab(temp.LastName, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col0,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col3,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col4,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col5,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col8,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col9,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col10,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col12,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col13,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col16,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col17,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col18,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col22,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col23,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col24,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col27,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col29,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col33,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col34,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col35,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col37,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col39,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col42,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col43,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col44,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col48,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col53,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col54,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col55,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col56,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col59,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col63,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col66,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col67,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col68,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col69,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col71,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col73,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col74,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col75,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col77,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col78,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col81,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col82,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col83,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col85,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col86,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col89,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col91,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col92,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col93,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col94,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col95,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col97,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col99,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col101,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col102,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col103,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col105,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col106,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col110,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col112,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col115,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col116,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col118,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col119,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col120,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col121,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col124,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col126,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col127,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col128,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col129,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col131,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col132,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col133,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col135,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col137,#T_dda952d2_0efd_11eb_97fb_0242ac1c0002row0_col139,#T_dda952d2_0efd_11eb_97fb_0242a ...

# %% [markdown]
# * 이제 우리는 Initial에서 Mr.등의 호칭을 뽑아내었고, 성을 뽑아내었습니다.
#
# * 머신이 알파벳보다는 숫자를 좋아 하므로 숫자로 바꿉니다.
#
# * 아, 그러기 전에 Dona를 처리해야지요.

# %%
temp.loc[temp['Initial'] == 'Dona'] # 'locate' 메소드 사용! (=찾아서 보여주는 함수)
#temp의 'Initial'열에서 'Dona'를 찾아서 보여줘라
# Out:
#      PassengerId  Survived  Pclass  ... Embarked Initial  LastName
# 414         1306       NaN       1  ...        C    Dona     Oliva
#
# [1 rows x 14 columns]

# %% [markdown]
# * 나이로 추측해서 Mrs.로 넣습니다.
# * 결측치를 처리하는 방법은 많으나 이렇게 하나일 경우에는 가장 적절한 추측을 사용하여 넣는 것도 괜찮습니다.
#
# locate method 학습 : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html

# %%
temp.loc[temp['Initial'] == 'Dona', 'Initial'] = 'Mrs'
#temp의 'Initial'에서 'Dona'를 찾으면, 'Initial'의 그 찾은 곳에다 'Mrs'를 대신 넣어줘라

# %%
pd.crosstab(temp.Initial, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col0,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col3,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col4,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col5,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col12,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col15,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col2,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col6,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col8,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col9,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col10,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col11,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col13,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col14,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col16{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col1,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col2,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col6,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col7,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col8,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col9,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col10,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col11,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col13,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col14,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col16,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col0,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col1,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col3,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col4,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col5,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col7,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col12,#T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col15{
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0.0</th>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col4" class="data row0 col4" >4</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col8" class="data row0 col8" >17</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col9" class="data row0 col9" >55</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col11" class="data row0 col11" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col12" class="data row0 col12" >436</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col13" class="data row0 col13" >26</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col14" class="data row0 col14" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col15" class="data row0 col15" >6</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row0_col16" class="data row0 col16" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1.0</th>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col2" class="data row1 col2" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col7" class="data row1 col7" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col8" class="data row1 col8" >23</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col9" class="data row1 col9" >127</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col10" class="data row1 col10" >2</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col11" class="data row1 col11" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col12" class="data row1 col12" >81</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col13" class="data row1 col13" >99</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col14" class="data row1 col14" >1</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col15" class="data row1 col15" >0</td>
#                         <td id="T_ddca9d34_0efd_11eb_97fb_0242ac1c0002row1_col16" class="data row1 col16" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# * Last name 은 전부 숫자로 바꿉니다.

# %%
# <성> 을 <숫자> 로 바꾸기 (<-머신은 알파벳보다 숫자를 잘 처리하므로) ->"factorize" 함수

temp['NumName'] = temp['LastName'].factorize()[0]       # [0] <- 번호를 붙이다가 다시 같은 이름이 나타나면 버리고 기존값을 주는 것을 의미함
#temp에 'NumName'이라는 새로운 열을 만들고 && temp의 'LastName'에서 factorize한 것을 넣는다

# %%
pd.crosstab(temp.NumName, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col0,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col5,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col6,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col7,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col12,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col13,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col14,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col16,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col17,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col18,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col20,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col25,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col27,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col28,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col29,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col32,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col33,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col36,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col38,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col39,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col40,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col43,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col44,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col45,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col46,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col47,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col48,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col51,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col54,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col56,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col57,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col60,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col61,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col64,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col66,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col67,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col68,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col70,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col71,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col72,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col75,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col78,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col81,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col82,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col83,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col84,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col85,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col86,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col88,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col89,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col90,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col94,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col95,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col96,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col97,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col98,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col99,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col102,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col103,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col104,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col105,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col106,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col107,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col108,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col109,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col111,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col112,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col114,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col117,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col118,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col119,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col120,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col122,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col123,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col125,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col126,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col127,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col130,#T_de7ee35c_0efd_11eb_97fb_0242ac1c0002row0_col131,#T_de7ee35c_0efd_11eb_97fb_0242a ...

# %%
temp.loc[temp['LastName'] == 'Ali']
# Out:
#      PassengerId  Survived  Pclass  ... Initial LastName  NumName
# 210          211       0.0       3  ...      Mr      Ali      182
# 784          785       0.0       3  ...      Mr      Ali      182
#
# [2 rows x 15 columns]

# %%
temp.loc[temp['LastName'] == 'James']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Initial, LastName, NumName]
# Index: []

# %% [markdown]
# * 보시다시피 같은 Last name에 같은 번호가 쓰여졌다.
#
# * 끝에 [0]은 라벨만 보고 번호를 붙이는 것으로 정말 unique한 것이란 것은 안 본다는 것입니다.
#
# * 자 이제 이름을 의미하는 중요한 요소 두 개를 숫자로 바꾸었으니 다음으로 갑니다.

# %%
temp.loc[temp['NumName'] == 27]
#결과 -> Name이 O에서 끊겼으니 실제로는 오류인 것이죠
# Out:
#      PassengerId  Survived  Pclass  ... Initial LastName  NumName
# 28            29       1.0       3  ...    Miss        O       27
# 47            48       1.0       3  ...    Miss        O       27
# 186          187       1.0       3  ...     Mrs        O       27
# 364          365       0.0       3  ...      Mr        O       27
# 459          460       0.0       3  ...      Mr        O       27
# 502          503       0.0       3  ...    Miss        O       27
# 552          553       0.0       3  ...      Mr        O       27
# 629          630       0.0       3  ...      Mr        O       27
# 653          654       1.0       3  ...    Miss        O       27
# 88           980       NaN       3  ...      Ms        O       27
# 358         1250       NaN       3  ...      Mr        O       27
# 380         1272       NaN       3  ...      Mr        O       27
#
# [12 rows x 15 columns]

# %% [markdown]
# ### "Sex" 분석
#
# * 함수를 만들어서 train파일을 보지요

# %%
train[['Sex','Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
def bag(col, target, title, title1):
    f,ax=plt.subplots(1,2,figsize=(12,5))
    train.groupby([col])[target].mean().plot(kind='bar', ax=ax[0])
    ax[0].set_title(title)
    sns.countplot(col, hue=target, data=train, ax=ax[1])
    ax[1].set_title(title1)
    plt.show()

bag('Sex','Survived','Survived per Sex','Sex Survived vs Not Survived')

# %% [markdown]
# * 배에 있던 남자의 수는 여자의 수보다 훨씬 많습니다. 여전히 생존 여성 수는 남성 수의 거의 두 배입니다. 선박 여성의 생존율은 약 75 % 인 반면 남성의 생존율은 약 18-19 %입니다.
#
# * 이 것은 남성/여성을 1,2로 나누면 될 것 같은 뻔해 보이는 것이지만 좀 더 새분화하면 좋아 보입니다.
# * 예를 들어 아기들은 아기이지, 남자인지 여자인지 구명보트 태울 때 안 물어 볼 것이기 때문입니다.
# * 오히려 (불행하게도) 귀족 아기인지 서민의 아기인지는 행과불행을 가를 수 있습니다 ㅠㅠ
# * 생존 Pclass별로 성별을 봅니다.

# %%
pd.crosstab([train.Sex, train.Survived],train.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row0_col0,#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row0_col1,#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row0_col3,#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row0_col2,#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row2_col1,#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row4_col0,#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row4_col1,#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row4_col2,#T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_e6bd62b4_0efd_11eb_97fb_0242ac1c0002row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# * 사회는 불공평 했으나 최소한 남자들의 신사도는 있었다고 할 수 있을 것 같습니다.

# %% [markdown]
# ### Age 분석
#
# * Age는 Continuous한 값입니다.
# * 빈칸이 많아서 빈칸처리가 결정적인 역할을 할 것 같습니다.
#
# * Age의 최대, 최소, 중간을 보겠습니다.

# %%
# math 모듈
import math
print(math.ceil(0.5)) #반올림
print(math.floor(0.5)) #내림

print(max([1, 2, 3])) #배열 중 가장 큰 수
print(max('Chevrolet')) #가장 늦게 오는 알파벳

print(min([1, 2, 3]))
print(min('Chevrolet')) #가장 빠른 알파벳


from statistics import mean
a = [5, 2, 3, 2]
avg = mean(a)
print(avg)
# Out:
# 1
# 0
# 3
# v
# 1
# C
# 3

# %%
print('Oldest Passenger was', data['Age'].max(), 'Years')
print('Youngest Passenger was', data['Age'].min(), 'Years')
print('Average Age on the ship was', int(data['Age'].mean()), 'Years')
# Out:
# Oldest Passenger was 80.0 Years
# Youngest Passenger was 0.17 Years
# Average Age on the ship was 29 Years

# %%
# 스왐플롯
sns.swarmplot(x=train['Survived'], y=train['Age']) # x축은 0(사망), 1(생존), y축은 나이
plt.xlabel("Survived")-
plt.ylabel("Age")
plt.show()
# Out:
#   File "<ipython-input-105-8a0eaa5fdadc>", line 3
#     plt.xlabel("Survived")-
#                            ^
# SyntaxError: invalid syntax

# %%
# 바이올린 플롯
f, ax = plt.subplots(1,2,figsize=(18,8)) # 일단 2개의 그림 (18, 8) 크기로 만들어 놓고,
sns.violinplot("Pclass", "Age", hue="Survived", data=train, split=True, ax=ax[0]) # 첫 번째 그림에서 수행 (0 축)
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10)) # 0에서 110까지 10단위로 나누는 것
sns.violinplot("Sex","Age", hue="Survived", data=train, split=True, ax=ax[1]) # 두 번째 그림에서 수행 (1 축)
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# #### 관찰 :
#
# 1) Pclass에 따라 어린이 수가 증가하고 10 세 미만의 어린이 (즉, 어린이)의 생존율은 Pclass에 상관없이 양호해 보입니다.
#
# 2) Pclass1에서 20-50세의 Passeneger의 생존 가능성은 높고 여성에게는 더 좋습니다.
#
# 3) 남성의 경우 생존 확률은 나이가 증가함에 따라 감소합니다.
#
#
# 우선 age의 빈칸 부터 해결 합니다.
#
# 앞에서 살펴본 것처럼 Age 항목에는 177 null 값이 있습니다. 이러한 NaN 값을 대체하기 위해 데이터 집합의 평균 수명을 지정할 수 있습니다.
#
# 그러나 문제는 평균 연령이 29 세를 4세 아이에게 할당 할 수 없습니다. 승객이 어떤 연령대에 있는지 알 수있는 방법이 있을까요? 이름에서 힌트를 찾아 봅니다.

# %% [markdown]
# * 그리고 Initial 별 평균 연령을 보고 Age에 적용 시키는 것이 좋을 것 같습니다.

# %%
temp.groupby('Initial').agg({'Age': ['mean', 'count']}) #이니셜 별 평균 연령 체크

# %%
# 이니셜 별 평균 연령을 빈값에 넣어 봅니다.

temp = temp.reset_index(drop=True)

temp['Age'] = temp.groupby('Initial')['Age'].apply(lambda x: x.fillna(x.mean()))

temp[31:50]

# %%
# 람다함수 공부

# 1. 단순 계산
a = 2
b = 2
print(a**b)


# 2. 이를 함수로 만든다면
def sample(a, b):
  print(a**b)

sample(2,2)

# 3. 이를 람다로 만들면
a = lambda x, y: x**y
print(a(2,2))

# %%
# 다른 샘플 예시
# 1
sample1 = lambda x, y, z: x+y+z
print(sample1(1, 2, 3))

# 2
def sample1(x, y, z):
  n = x+y+z
  print(n)

sample1(1, 2, 3)

# 3
sample2 = lambda x, y, z: x*y*z
print(sample2(1, 2, 3))

# 4
z = (lambda x, y: x+y)(10, 20)
print(z)

# %%
# 람다의 map 함수를 해봅니다.
print(list(map(lambda x: x**2, [5, 6, 7, 8, 9])))

# %%
# 람다의 filter 함수를 해봅니다.
mylist = [1, 2, 3]
print(list(filter(lambda x: x>2, mylist)))

# %% [markdown]
# [람다함수 공부](https://trinket.io/joshua-mobile-choi-1756/courses/python-3-4#/tasks/task-34-lambda)
#
# [람다함수 메소드](https://trinket.io/joshua-mobile-choi-1756/courses/python-3-4#/tasks/task-35-lambda-and-functions)
#
# * 이제 Initial을 좀 정리합니다.

# %%
# 왜??
temp['Initial'].replace(['Capt', 'Col', 'Countess', 'Don', 'Dona' , 'Dr', 'Jonkheer', 'Lady', 'Major', 'Master',
                         'Miss'  ,'Mlle', 'Mme', 'Mr', 'Mrs', 'Ms', 'Rev', 'Sir'], 
                        ['Sacrificed', 'Respected', 'Nobles', 'Mr', 'Mrs', 'Respected', 'Mr', 'Nobles', 'Respected',
                         'Kids', 'Miss', 'Nobles', 'Nobles', 'Mr', 'Mrs', 'Nobles', 'Sacrificed', 'Nobles'],inplace=True)
temp['Initial'].replace(['Kids', 'Miss', 'Mr', 'Mrs', 'Nobles', 'Respected', 'Sacrificed'], [4, 4, 2, 5, 6, 3, 1], inplace=True)

# %%
# qcut과 cut
temp['Age_Range'] = pd.qcut(temp['Age'], 10)

# %%
survpct('Age_Range')
# Out:
# Age_Range
# (0.169, 14.0]    0.584416
# (14.0, 19.0]     0.390805
# (19.0, 22.0]     0.283582
# (22.0, 25.0]     0.371429
# (25.0, 28.0]     0.393443
# (28.0, 31.0]     0.393939
# (31.0, 36.0]     0.483516
# (36.0, 42.0]     0.378788
# (42.0, 50.0]     0.384615
# (50.0, 80.0]     0.343750
# Name: Survived, dtype: float64

# %%
temp['Agroup'] = 0

temp.loc[temp['Age'] < 1.0, 'Agroup'] = 1
temp.loc[(temp['Age'] >=1.0) & (temp['Age'] <= 3.0), 'Agroup'] = 2
temp.loc[(temp['Age'] > 3.0) & (temp['Age'] < 11.0), 'Agroup'] = 7
temp.loc[(temp['Age'] >= 11.0) & (temp['Age'] < 15.0), 'Agroup'] = 13
temp.loc[(temp['Age'] >= 15.0) & (temp['Age'] < 18.0), 'Agroup'] = 16
temp.loc[(temp['Age'] >= 18.0) & (temp['Age'] <=  20.0), 'Agroup'] = 18
temp.loc[(temp['Age'] > 20.0) & (temp['Age'] <= 22.0), 'Agroup'] = 21
temp.loc[(temp['Age'] > 22.0) & (temp['Age'] <= 26.0), 'Agroup'] = 24
temp.loc[(temp['Age'] > 26.0) & (temp['Age'] <= 30.0), 'Agroup'] = 28
temp.loc[(temp['Age'] > 30.0) & (temp['Age'] <= 32.0), 'Agroup'] = 31
temp.loc[(temp['Age'] > 32.0) & (temp['Age'] <= 34.0), 'Agroup'] = 33
temp.loc[(temp['Age'] > 34.0) & (temp['Age'] <= 38.0), 'Agroup'] = 36
temp.loc[(temp['Age'] > 38.0) & (temp['Age'] <= 52.0), 'Agroup'] = 45
temp.loc[(temp['Age'] > 52.0) & (temp['Age'] <= 75.0), 'Agroup'] = 60
temp.loc[temp['Age'] > 75.0, 'Agroup'] = 78

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... NumName     Age_Range  Agroup
# 0            1       0.0       3  ...       0  (19.0, 22.0]      21
# 1            2       1.0       1  ...       1  (36.0, 42.0]      36
# 2            3       1.0       3  ...       2  (25.0, 28.0]      24
# 3            4       1.0       1  ...       3  (31.0, 36.0]      36
# 4            5       0.0       3  ...       4  (31.0, 36.0]      36
#
# [5 rows x 17 columns]

# %% [markdown]
# * Age는 그룹화 시키면 좋으나 학습을 위해서 그냥 놓아두고, 그룹화 연습은 Fare로 하겠습니다.

# %% [markdown]
# * 위를 보고 sex를 남,녀, 1세 이하 Baby로 나누겠습니다. 1,2,3번을 주지오

# %%
## 할당 (참고!!!!!!!)

temp.loc[(temp['Sex'] == 'male'), 'Sex'] = 1
temp.loc[(temp['Sex'] == 'female'), 'Sex'] = 2
temp.loc[(temp['Age'] < 1), 'Sex'] = 3

# %%
# 뭐하는 함수??
survpct('Sex')
# Out:
# Sex
# 1    0.181818
# 2    0.740385
# 3    1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# #### Family or Alone?
# * "SibSp" + "Parch" 분석
#
# * SibSp - 이 항목은 탑승자가 혼자인지 또는 가족과 함께 있는지를 나타냅니다.
# * *Sibling = 형제, 자매, 의붓 형제, 이복 누이
#
# * Spouse = 남편, 아내
#
# * Parch는 부모와 함께 탔는지를 봅니다.
#
# * 이 그룹 둘을 'Alone"그룹과 "Family'그룹으로 나눕니다.

# %%
temp.loc[(temp['SibSp'] == 0) & (temp['Parch'] == 0), 'Alone'] = 1

# %%
temp['Family'] = temp['Parch'] + temp['SibSp'] + 1

# %%
temp.head(n=10)
# Out:
#    PassengerId  Survived  Pclass  ... Agroup Alone  Family
# 0            1       0.0       3  ...     21   NaN       2
# 1            2       1.0       1  ...     36   NaN       2
# 2            3       1.0       3  ...     24   1.0       1
# 3            4       1.0       1  ...     36   NaN       2
# 4            5       0.0       3  ...     36   1.0       1
# 5            6       0.0       3  ...      0   1.0       1
# 6            7       0.0       1  ...     60   1.0       1
# 7            8       0.0       3  ...      2   NaN       5
# 8            9       1.0       3  ...     28   NaN       3
# 9           10       1.0       2  ...     13   NaN       2
#
# [10 rows x 19 columns]

# %%
survpct('Family')
# Out:
# Family
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# * 크로스 탭은 다시 식구 많은 쪽은 Pclass3에 있음을 보여줍니다.
#
# * 여기에서도 결과는 매우 비슷합니다. 부모와 함께 탑승 한 승객은 생존 가능성이 더 높습니다. 그러나 숫자가 올라 갈수록 줄어 듭니다.
#
# * 생존 가능성은 배에 1-3 명의 부모가있는 누군가에게 좋습니다. 혼자 또한 생존 가능성이 낮은 것으로 판명되고 가족이 4 명이상 있으면 생존 가능성이 줄어 듭니다. 이는 소수의 가족들이 있는 귀족층이 생존하고, 혼자가 많은 젊은 이들은 양보를 할 수 밖에 없고, 가족이 많은 사람들(특히 귀족이 아닌 3등칸 사람들)은 전원이 타지 못 하면 어느 누구도 탈 수가 없는 비극적인 당시 상황을 보여 줍니다.

# %%
bag('Parch', 'Survived', 'Survived per Parch', 'Parch Survived vs Not Survived')

# %%
# 크로스탭으로 생존율 현황 보기
pd.crosstab([temp.Family, temp.Survived], temp.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row0_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row3_col0{
#             background-color:  #c3e166;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row0_col1{
#             background-color:  #a1d066;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row0_col2{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row0_col3{
#             background-color:  #95ca66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row1_col0{
#             background-color:  #bbdd66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row1_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row1_col2{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row1_col3{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row2_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row2_col1{
#             background-color:  #e9f466;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row2_col2,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row2_col3{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row3_col1{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row3_col2,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row5_col2{
#             background-color:  #f5fa66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row3_col3{
#             background-color:  #e7f366;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row4_col0{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row4_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row7_col1{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row4_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row4_col3{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row5_col0{
#             background-color:  #eaf466;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row5_col1{
#             background-color:  #e2f066;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row5_col3{
#             background-color:  #eff766;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row6_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row8_col3,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row9_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row10_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row11_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row13_col2{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row6_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row10_col3,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row12_col2{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row6_col2,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row6_col3,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row9_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row11_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row12_col3,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row15_col3{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row7_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row7_col3{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row7_col2,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row14_col2,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row15_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row8_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row8_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row9_col2,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row9_col3,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row10_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row11_col2,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row11_col3,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row12_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row12_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row13_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row13_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row13_col3,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row14_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row14_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row14_col3,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row15_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row15_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row8_col2{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row10_col2{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row16_col0,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row16_col1,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row16_col2,#T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row16_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Family</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>1</th>
#                         <th id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002level1_row0" class="row_heading level1 row0" >0.0</th>
#                         <td id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row0_col0" class="data row0 col0" >51</td>
#                         <td id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row0_col1" class="data row0 col1" >68</td>
#                         <td id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row0_col2" class="data row0 col2" >255</td>
#                         <td id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row0_col3" class="data row0 col3" >374</td>
#             </tr>
#             <tr>
#                                 <th id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002level1_row1" class="row_heading level1 row1" >1.0</th>
#                         <td id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row1_col0" class="data row1 col0" >58</td>
#                         <td id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row1_col1" class="data row1 col1" >36</td>
#                         <td id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row1_col2" class="data row1 col2" >69</td>
#                         <td id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002row1_col3" class="data row1 col3" >163</td>
#             </tr>
#             <tr>
#                         <th id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>2</th>
#                         <th id="T_b0b9b61c_0efe_11eb_97fb_0242ac1c0002level1_row2" class="row_heading level1 row2" >0.0</th>
#                         <td id="T_b0b9b61c_

# %% [markdown]
# #### "Ticket"분석
# * Ticket의 형태를 보겠습니다.

# %%
temp.Ticket.head()
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %% [markdown]
# * 도무지 감이 안 잡히는 배열입니다.
# * 빈칸이 없는지 보겠습니다.

# %%
temp.Ticket.isnull().any()
# Out:
# False

# %% [markdown]
# * 티켓에서 영문있는 것과 숫자만 있는 것을 따봅니다.

# %%
temp['Initick'] = temp.Ticket.str.extract('^([A-Za-z0-9]+)')

temp = temp.reset_index(drop=True)  # 복사한 항목들을 사용하다보면 'ValueError: cannot reindex from a duplicate axis` 요런 에러가 나오는 경우가 많은데 이런 것은 요 코드로 리셋을 한 번 해주면 됩니다.

temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... Alone Family  Initick
# 0            1       0.0       3  ...   NaN      2        A
# 1            2       1.0       1  ...   NaN      2       PC
# 2            3       1.0       3  ...   1.0      1     STON
# 3            4       1.0       1  ...   NaN      2   113803
# 4            5       0.0       3  ...   1.0      1   373450
#
# [5 rows x 20 columns]

# %%
temp['Initick'] = temp.Ticket.str.extract('^([A-Za-z]+)')

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... Alone Family  Initick
# 0            1       0.0       3  ...   NaN      2        A
# 1            2       1.0       1  ...   NaN      2       PC
# 2            3       1.0       3  ...   1.0      1     STON
# 3            4       1.0       1  ...   NaN      2      NaN
# 4            5       0.0       3  ...   1.0      1      NaN
#
# [5 rows x 20 columns]

# %%
temp['NumTicket'] = temp['Initick'].factorize()[0]

# %%
temp.head(n=15)
# Out:
#     PassengerId  Survived  Pclass  ... Family Initick  NumTicket
# 0             1       0.0       3  ...      2       A          0
# 1             2       1.0       1  ...      2      PC          1
# 2             3       1.0       3  ...      1    STON          2
# 3             4       1.0       1  ...      2     NaN         -1
# 4             5       0.0       3  ...      1     NaN         -1
# 5             6       0.0       3  ...      1     NaN         -1
# 6             7       0.0       1  ...      1     NaN         -1
# 7             8       0.0       3  ...      5     NaN         -1
# 8             9       1.0       3  ...      3     NaN         -1
# 9            10       1.0       2  ...      2     NaN         -1
# 10           11       1.0       3  ...      3      PP          3
# 11           12       1.0       1  ...      1     NaN         -1
# 12           13       0.0       3  ...      1       A          0
# 13           14       0.0       3  ...      7     NaN         -1
# 14           15       0.0       3  ...      1     NaN         -1
#
# [15 rows x 21 columns]

# %%
temp.groupby('NumTicket')['Survived'].mean().to_frame().plot(kind='hist')
plt.title('Distribution of survival rate for different tickets');

# %% [markdown]
# ### "Fare" 분석

# %%
print('Highest Fare was:', temp['Fare'].max())
print('Lowest Fare was:', temp['Fare'].min())
print('Average Fare was:', temp['Fare'].mean())

# %%
f,ax=plt.subplots(1, 3, figsize=(20, 6))
sns.distplot(train[train['Pclass'] == 1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(train[train['Pclass'] == 2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(train[train['Pclass'] == 3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# * Pclass1의 승객 요금에는 큰 분포가있는 것으로 보이며 불연속 값으로 변환 할 수 있습니다.
# * Fare를 그룹으로 나누어 놓겠습니다.
# * qcut을 활용하면 원하는 조각으로 데이터를 나누어 줍니다.
# * cut와 qcut의 차이

# %%
def groupmean(a,b):
    return temp.groupby([a])[b].mean().to_frame().style.background_gradient(cmap='summer_r')

temp['Fare_Range'] = pd.qcut(train['Fare'], 10)
groupmean('Fare_Range', 'Fare')

# %% [markdown]
# * Fare를 그룹화 시킵니다. Fgroup이라고 이름 짓겠습니다.

# %% [markdown]
# 0 and below -> 0
#
# 7.125 and below-> 5.0
#
# 7.9 and below-> 7.5
#
# 8.03 or less-> 8.0
#
# Less than 10.5-> 9.5
#
# Less than 23-> 16.0
#
# 27.8 and below-> 25.5
#
# 51 and below-> 38
#
# 73.5 and below-> 62
#
# Over 73.5-> 100

# %%
temp['Fgroup'] = 0

temp.loc[temp['Fare'] <= 0,'Fgroup'] = 0
temp.loc[(temp['Fare'] > 0) & (temp['Fare'] <= 7.125), 'Fgroup'] = 1
temp.loc[(temp['Fare'] > 7.125) & (temp['Fare'] <= 7.9), 'Fgroup'] = 2
temp.loc[(temp['Fare'] > 7.9) & (temp['Fare'] <= 8.03), 'Fgroup'] = 3
temp.loc[(temp['Fare'] > 8.03) & (temp['Fare'] < 10.5), 'Fgroup'] = 4
temp.loc[(temp['Fare'] >= 10.5) & (temp['Fare'] < 23.0), 'Fgroup'] = 5
temp.loc[(temp['Fare'] >= 23.0) & (temp['Fare'] <= 27.8), 'Fgroup'] = 6
temp.loc[(temp['Fare'] > 27.8) & (temp['Fare'] <= 51.0), 'Fgroup'] = 7
temp.loc[(temp['Fare'] > 51.0) & (temp['Fare'] <= 73.5), 'Fgroup'] = 8
temp.loc[temp['Fare'] > 73.5, 'Fgroup'] = 9

temp.head()

# %% [markdown]
# ### "Cabin" 분석
# * cabin 의 위치에 따라 달라지는 것이 있는지 보겠습니다.

# %%
temp.Cabin.value_counts().head(10)

# %%
temp.Cabin.isnull().sum()

# %% [markdown]
# * 빈칸이 무척 많습니다.
# * Cabin에 비어 있는 것이 많아 이를 다른 분류로 일단 잡고 기존 것은 이니셜로 분류합니다.
# * 빈 것은 X로 구분하려는데 이 또한 1,2,3 Pclass와 연동될 것 같으니 비어있고 1등급은 X, 2등급은 Y, 3등급은 Z로 하겠습니다.

# %%
temp['Inicab'] = 0
temp['Inicab'] = temp['Cabin'].str.extract('^([A-Za-z]+)')
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 1)), 'Inicab'] = 'X'
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 2)), 'Inicab'] = 'Y'
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 3)), 'Inicab'] = 'Z'
    
temp.head()

# %%
temp['Inicab'] = temp['Inicab'].factorize()[0]
    
temp[11:20]

# %% [markdown]
# #### "Embarked" 분석

# %%
pd.crosstab([temp.Embarked, temp.Pclass], [temp.Sex, temp.Survived], margins=True).style.background_gradient(cmap='summer_r')

# %% [markdown]
# * 승선 장소 별로 생존 확률

# %%
sns.factorplot('Embarked', 'Survived', data=temp)
fig = plt.gcf()
fig.set_size_inches(5, 3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked', data=temp, ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=temp, ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=temp, ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=temp, ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# 1) 포트 C의 생존 가능성은 0.55 정도이며 S는 가장 낮습니다.S에서 탑승 최대. 대다수는 Pclass3
#
# 2) C의 승객들은 많은 비율이 살아남았습니다. 그 이유는 Pclass1 및 Pclass2 승객이 많아서 일 것입니다
#
# 3) Embark S는 대부분의 부자들이 탑승한 항구지만 생존 가능성은 낮습니다. Pclass3의 승객도 많았습니다.
#
# 4) 포트 Q는 승객의 거의 95 %가 Pclass3
#
# * 빈칸이 두개 있는데 보겠습니다.

# %%
temp.loc[(temp.Embarked.isnull())]

# %% [markdown]
# * 두 사람의 티켓 번호가 같습니다.
# * 혹시 같은 티켓 번호가 있는 다른 사람이 있는지 봅니다.

# %%
temp.loc[(temp.Ticket == '113572')]

# %% [markdown]
# * 가장 비슷한 번호를 찾아 보겠습니다.

# %%
temp.sort_values(['Ticket'], ascending = True)[55:70]

# %% [markdown]
# * 앞 뒤로 모두 S이고 Pclass도 모두 1인 것으로 봐서 S일 가능성이 큽니다.

# %%
temp.loc[(temp.Embarked.isnull()), 'Embarked'] = 'S'

# %%
temp.loc[(temp.Embarked.isnull())]

# %%
temp['Embarked'] = temp['Embarked'].factorize()[0]
    
temp[11:20]

# %% [markdown]
# <a id = "part5"></a>
# ## Part 5: Feature Engineering
# [Go to the Table of Contents](#table_of_contents)

# %% [markdown]
# * 문자를 숫자로 바꾸는 것도 Feature Engineering의 일부이나 위에서 대부분 다 했습니다.

# %% [markdown]
# ### 항목 추가하기
#
# * 위에 추가 항목을 몇 개 만들어 보았습니다.
#
# * 그래도 몇 개 더 만들어 볼까요?
#
# * 5개 정도 만들어 봅니다.
#
# * Priority - Nobles, Women in Pclass 1 & 2, Babies under 1, Kids under 17 in Pclass 1 & 2, higher fare, Women in Pclass 3 and so on
# * FH - Female Higher Survival Group
# * MH - Male Higher Survival Group
# * FL - Female Lower Surival Group
# * ML - Male Lower Survival Group

# %% [markdown]
# * Priority - (1) Nobles (2) Women in Pclass 1  (3) Babies under 1 (4) Kids under 17 in Pclass 1 & 2  (5) Women in Pclass 2 (6) Higher Fare

# %%
survpct('Initial')

# %%
survpct('Pclass')

# %%
survpct('Sex')

# %%
survpct('Age').head()

# %%
survpct('Fgroup')

# %%
temp['Priority'] = 0
temp.loc[(temp['Initial'] == 6), 'Priority'] = 1
temp.loc[(temp['Pclass'] == 1) & (temp['Sex'] == 2), 'Priority'] = 2
temp.loc[(temp['Age'] < 1), 'Priority'] = 3
temp.loc[(temp['Pclass'] == 1) & (temp['Age'] <= 17), 'Priority'] = 4
temp.loc[(temp['Pclass'] == 2) & (temp['Age'] <= 17), 'Priority'] = 5
temp.loc[(temp['Pclass'] == 2) & (temp['Sex'] == 2), 'Priority'] = 6
temp.loc[(temp['Fgroup'] == 9), 'Priority'] = 7

# %%
survpct('Priority')

# %%
temp.Priority.value_counts()

# %%
survpct('Family')

# %%
survpct('Fgroup')

# %%
temp['FH'] = 0
temp.loc[(temp['Sex'] == 1), 'FH'] = 0
temp.loc[(temp['Sex'] == 2), 'FH'] = 1
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 2), 'FH'] = 2
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 3), 'FH'] = 3
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 4), 'FH'] = 4
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 1) & (temp['Pclass'] == 1), 'FH'] = 5
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 1) & (temp['Pclass'] == 2), 'FH'] = 6
temp.loc[(temp['Sex'] == 2) & (temp['Fgroup'] == 3), 'FH'] = 7
temp.loc[(temp['Sex'] == 2) & (temp['Fgroup'] >= 5), 'FH'] = 8

# %%
survpct('FH')

# %%
temp.FH.value_counts()

# %%
temp['MH'] = 0
temp.loc[(temp['Sex'] == 2), 'MH'] = 0
temp.loc[(temp['Sex'] == 1), 'MH'] = 1
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 2), 'MH'] = 2
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 3), 'MH'] = 3
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 4), 'MH'] = 4
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 1) & (temp['Pclass'] == 1), 'MH'] = 5
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 1) & (temp['Pclass'] == 2), 'MH'] = 6
temp.loc[(temp['Sex'] == 1) & (temp['Fgroup'] == 3), 'MH'] = 7
temp.loc[(temp['Sex'] == 1) & (temp['Fgroup'] >= 5), 'MH'] = 8

# %%
survpct('MH')

# %%
temp.MH.value_counts()

# %%
temp['FL'] = 0
temp.loc[(temp['Sex'] == 1), 'FL'] = 0
temp.loc[(temp['Sex'] == 2) & (temp['Fgroup'] < 5), 'FL'] = 1
temp.loc[(temp['Sex'] == 2) & (temp['Fgroup'] != 3), 'FL'] = 2
temp.loc[(temp['Sex'] == 2) & (temp['FH'] == 1), 'FL'] = 3
temp.loc[(temp['Sex'] == 2) & (temp['Family'] < 2), 'FL'] = 4
temp.loc[(temp['Sex'] == 2) & (temp['Family'] > 4), 'FL'] = 5
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 1) & (temp['Pclass'] == 3), 'FL'] = 6

# %%
survpct('FL')

# %%
temp.FL.value_counts()

# %%
temp['ML'] = 0
temp.loc[(temp['Sex'] == 2), 'ML'] = 0
temp.loc[(temp['Sex'] == 1) & (temp['Fgroup'] < 5), 'ML'] = 1
temp.loc[(temp['Sex'] == 1) & (temp['Fgroup'] != 3), 'ML'] = 2
temp.loc[(temp['Sex'] == 1) & (temp['MH'] <7), 'ML'] = 3
temp.loc[(temp['Sex'] == 1) & (temp['Family'] < 2), 'ML'] = 4
temp.loc[(temp['Sex'] == 1) & (temp['Family'] > 4), 'ML'] = 5
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 1) & (temp['Pclass'] == 3), 'ML'] = 6

# %%
survpct('ML')

# %%
temp.ML.value_counts()

# %% [markdown]
# <a id = "part6"></a>
# ## Part 6: 마지막 항목 결정
# [Go to the Table of Contents](#table_of_contents)

# %%
temp['F1'] = temp['Priority']
temp['F2'] = temp['FH']
temp['F3'] = temp['MH']
temp['F4'] = temp['FL']
temp['F5'] = temp['ML']
temp['F6'] = temp['Initial']
temp['F7'] = temp['Fgroup']
temp['F8'] = temp['NumName']
temp['F9'] = temp['NumTicket']
temp['F10'] = temp['Family']
temp['F11'] = temp['Embarked']
temp['F12'] = temp['Sex']
temp['F13'] = temp['Pclass']

# %% [markdown]
# * 이제 다음 단계로 갑니다.

# %% [markdown]
# * 두개의 새로운 데이터 프레임을 만듭니다. 하나는 레이블 인코딩 다른 하나는 원핫 인코딩 (둘이 꼭 필요한 것이 아니라 연습이나 두 가지 방 법 모두 사용해봄)

# %% [markdown]
# * 대표적인 인코딩에 Label Encoding이 있는데 이는 각 항목의 값을 서열화 시켜 주~욱 줄세운 것이라 생각하시면 됩니다.
# * 그 외에 자주쓰는 One Hot Encoding 같은 경우 열 내에서의 항목을 나누어서 (열이 주~욱 늘어나며) 이를 0이냐 1이냐로 구분해 놓은 것입니다.

# %% [markdown]
# * 다시 말씀 드려서 레이블 인코딩은 줄을 세워서 번호를 부여하는 것이고, 원핫인코딩은 긴가 아닌가 두 가지입니다.
#
# * 예를들어 나이별로 줄을 세워 너는 5번, 너는 6번이런식이 레이블 인코딩이고
#
# * 16살이야? 1, 16살 아냐 0 ..그 다음 17살이야? 1 17살 아냐 0 ..이런 식이라 열의 수가 무지하게 늘어납니다.

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %% [markdown]
# 새로운 Data Frame을 만듭니다.

# %%
dfl = pd.DataFrame() # for label encoding

# %%
good_columns = ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11', 'F12', 'F13']
dfl[good_columns] = temp[good_columns]

# %%
dfl.head()

# %%
dfh = dfl.copy()

# %%
dfl_enc = dfl.apply(LabelEncoder().fit_transform)
                          
dfl_enc.head()

# %%
one_hot_cols = dfh.columns.tolist()
dfh_enc = pd.get_dummies(dfh, columns=one_hot_cols)

dfh_enc.head()

# %% [markdown]
# <a id = "part7"></a>
# ## Part 7:  머신러닝 모델 만들기
# [Go to the Table of Contents](#table_of_contents)

# %% [markdown]
# * 자, 이제 머신 러닝 모델을 만들어 보지요.
# * 우선 인코딩한 파일을 train과 test로 아까 구분해 놓은 행으로 쪼갭니다

# %%
train = dfh_enc[:ntrain]
test = dfh_enc[ntrain:]

# %%
X_test = test
X_train = train

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
ran = RandomForestClassifier(random_state=1)
knn = KNeighborsClassifier()
log = LogisticRegression()
xgb = XGBClassifier()
gbc = GradientBoostingClassifier()
svc = SVC(probability=True)
ext = ExtraTreesClassifier()
ada = AdaBoostClassifier()
gnb = GaussianNB()
gpc = GaussianProcessClassifier()
bag = BaggingClassifier()

# 리스트 준비
models = [ran, knn, log, xgb, gbc, svc, ext, ada, gnb, gpc, bag]         
model_names = ['Random Forest', 'K Nearest Neighbour', 'Logistic Regression', 'XGBoost', 'Gradient Boosting', 'SVC', 'Extra Trees', 'AdaBoost', 'Gaussian Naive Bayes', 'Gaussian Process', 'Bagging Classifier']
scores = {}

# 이어서 연속적으로 모델을 학습 시키고 교차 검증합니다.
for ind, mod in enumerate(models):
    mod.fit(X_train, y_train)
    acc = cross_val_score(mod, X_train, y_train, scoring = "accuracy", cv = 10)
    scores[model_names[ind]] = acc

# %% [markdown]
# * [리스트 학습](https://trinket.io/joshua-mobile-choi-1756/courses/python-3-4#/tasks/task-14-list)
# * [딕쇼너리 학습](https://trinket.io/joshua-mobile-choi-1756/courses/python-3-4#/tasks/task-16-dictionary)

# %%
# 결과 테이블을 만듭니다.
results = pd.DataFrame(scores).T
results['mean'] = results.mean(1)

result_df = results.sort_values(by='mean', ascending=False)#.reset_index()
result_df.head(11)

# %%
result_df = result_df.drop(['mean'], axis=1)
sns.boxplot(data=result_df.T, orient='h')
plt.title('Machine Learning Algorithm Accuracy Score \n')
plt.xlabel('Accuracy Score (%)');

# %%
# 중요도를 보는 함수를 만듭니다.
def importance_plotting(data, xlabel, ylabel, title, n=20):
    sns.set(style="whitegrid")
    ax = data.tail(n).plot(kind='barh')
    
    ax.set(title=title, xlabel=xlabel, ylabel=ylabel)
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)
    plt.show()

# %%
# 데이터 프레임에 항목 중요도를 넣습니다.
fi = {'Features':train.columns.tolist(), 'Importance':xgb.feature_importances_}
importance = pd.DataFrame(fi, index=fi['Features']).sort_values('Importance', ascending=True)

# %%
# 그래프 제목
title = 'Top 20 most important features in predicting survival on the Titanic: XGB'

# 그래프 그리기
importance_plotting(importance, 'Importance', 'Features', title, 20)

# %%
# 중요도를 데이터프레임에 넣습니다. Logistic regression에서는 중요도보다 coefficients를 사용합니다. 
# 아래는 Features라는 열에 트레인의 열들의 이름을 리스트로 만들어서 넣고 Importance에는 Logistic regression에는 coefficient를 바꾸어 넣어라는 넘파이 명령입니다.(즉 가로를 세로로)
fi = {'Features':train.columns.tolist(), 'Importance':np.transpose(log.coef_[0])}
importance = pd.DataFrame(fi, index=fi['Features']).sort_values('Importance', ascending=True)
# 그래프 타이틀
title = 'Top 20 important features in predicting survival on the Titanic: Logistic Regression'

# 그래프 그리기
importance_plotting(importance, 'Importance', 'Features', title, 20)

# %%
# 5가지 모델에 대한 항목 중요도 얻기
gbc_imp = pd.DataFrame({'Feature':train.columns, 'gbc importance':gbc.feature_importances_})
xgb_imp = pd.DataFrame({'Feature':train.columns, 'xgb importance':xgb.feature_importances_})
ran_imp = pd.DataFrame({'Feature':train.columns, 'ran importance':ran.feature_importances_})
ext_imp = pd.DataFrame({'Feature':train.columns, 'ext importance':ext.feature_importances_})
ada_imp = pd.DataFrame({'Feature':train.columns, 'ada importance':ada.feature_importances_})

# 이를 하나의 데이터프레임으로
importances = gbc_imp.merge(xgb_imp, on='Feature').merge(ran_imp, on='Feature').merge(ext_imp, on='Feature').merge(ada_imp, on='Feature')

# 항목당 평균 중요도
importances['Average'] = importances.mean(axis=1)

# 랭킹 정하기
importances = importances.sort_values(by='Average', ascending=False).reset_index(drop=True)

# %% [markdown]
# <a id = "part8"></a>
# ## Part 8: 중요도에 따라 모델 재 설정
# [Go to the Table of Contents](#table_of_contents)

# %%
# 중요도를 다시 데이터 프레임에 넣기
fi = {'Features':importances['Feature'], 'Importance':importances['Average']}
importance = pd.DataFrame(fi).set_index('Features').sort_values('Importance', ascending=True)

# 그래프 타이틀
title = 'Top 20 important features in predicting survival on the Titanic: 5 model average'

# 그래프 보기
importance_plotting(importance, 'Importance', 'Features', title, 20)

# %%
importance1 = importance[-381:]

importance1[371:381]

# %%
# 영양가 있는 380개만 넣기
mylist = list(importance1.index)

# %%
train1 = pd.DataFrame()
test1 = pd.DataFrame()

for i in mylist:
    train1[i] = train[i]
    test1[i]= test[i]
    
train1.head()

# %%
train = train1
test = test1

# 모델의 변수를 다시 정의하고
X_train = train
X_test = test

# 바꿉니다.
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
ran = RandomForestClassifier(random_state=1)
knn = KNeighborsClassifier()
log = LogisticRegression()
xgb = XGBClassifier(random_state=1)
gbc = GradientBoostingClassifier(random_state=1)
svc = SVC(probability=True)
ext = ExtraTreesClassifier(random_state=1)
ada = AdaBoostClassifier(random_state=1)
gnb = GaussianNB()
gpc = GaussianProcessClassifier()
bag = BaggingClassifier(random_state=1)

# 리스트 준비
models = [ran, knn, log, xgb, gbc, svc, ext, ada, gnb, gpc, bag]         
model_names = ['Random Forest', 'K Nearest Neighbour', 'Logistic Regression', 'XGBoost', 'Gradient Boosting', 'SVC', 'Extra Trees', 'AdaBoost', 'Gaussian Naive Bayes', 'Gaussian Process', 'Bagging Classifier']
scores2 = {}

# 학습 및 교차 검증
for ind, mod in enumerate(models):
    mod.fit(X_train, y_train)
    acc = cross_val_score(mod, X_train, y_train, scoring = "accuracy", cv = 10)
    scores2[model_names[ind]] = acc

# %%
# 결과 테이블을 만듭니다.
results = pd.DataFrame(scores2).T
results['mean'] = results.mean(1)

result_df = results.sort_values(by='mean', ascending=False)#.reset_index()
result_df.head(11)
result_df = result_df.drop(['mean'], axis=1)
sns.boxplot(data=result_df.T, orient='h')
plt.title('Machine Learning Algorithm Accuracy Score \n')
plt.xlabel('Accuracy Score (%)');

# %% [markdown]
# <a id = "part9"></a>
# ## Part 9: 하이퍼 파라미터 튜닝
# [Go to the Table of Contents](#table_of_contents)
#
# ### SVC
# * Scikit-Learn에서는 3가지 모형 최적화 도구를 지원하는데 validation_curve/ GridSearchCV/ ParameterGrid이다
# * fit 메소드를 호출하면 grid search가 자동으로 여러개의 내부 모형을 생성하고 이를 모두 실행시켜서 최적 파라미터를 찾는다.
#
# * bestscore는 최고 점수이고 best estimator는 최고 점수를 낸 파라미터를 가진 모형
# * c값과 gamma값은 10의 배수로 일반적으로 한다.
# * 감마 매개 변수는 단일 학습 예제의 영향이 도달하는 정도를 정의하며 낮은 값은 'far'를, 높은 값은 'close'를 나타냅니다. 감마 매개 변수는 서포트 벡터로 모델에 의해 선택된 샘플의 영향 반경의 역으로 볼 수 있습니다.
# * C 매개 변수는 의사 결정 표면의 단순성에 대한 훈련 예제의 오 분류를 제거합니다. C가 낮을수록 결정 표면이 매끄럽고 높은 C는 모델이 더 많은 샘플을 서포트 벡터로 자유롭게 선택할 수 있도록하여 모든 학습 예제를 올바르게 분류하는 것을 목표로합니다.
# * Verbose는 불리안 값으로 True로 넣으면 꼬치 꼬치 다 알려주는데, 대신 시간이 좀 더 오래 걸립니다.
# * cv =5는 5 fold로 교차 검증한다는 뜻입니다.

# %%
# 파라미터 서치
Cs = [0.01, 0.1, 1, 5, 10, 15, 20, 50]
gammas = [0.001, 0.01, 0.1]

# 파라미터 그리드 셋팅
hyperparams = {'C': Cs, 'gamma' : gammas}

# 교차검증
gd=GridSearchCV(estimator = SVC(probability=True), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

# 모델 fiting 및 결과
gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### Gradient Boosting Classifier
# * learning_rate는 각 트리의 기여를 줄이는 역할을 합니다.
# * n_estimator는 각 경우의 트리 숫자입니다.

# %%
learning_rate = [0.01, 0.05, 0.1, 0.2, 0.5]
n_estimators = [100, 1000, 2000]
max_depth = [3, 5, 10, 15]

hyperparams = {'learning_rate': learning_rate, 'n_estimators': n_estimators}

gd=GridSearchCV(estimator = GradientBoostingClassifier(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### Logistic Regression
# * Penalty - L1 을 사용하는 회귀 모델을 Lasso Regression이라고하고 L2를 사용하는 모델을 Ridge Regression이라고합니다. 이 둘의 주요 차이점은 페널티입니다. 릿지 회귀는 손실 함수에 페널티 항으로 계수의 "제곱 크기"를 추가합니다. L2-norm이 오차를 제곱하기 때문에 (오류> 1 인 경우 로트가 증가 함) 모델은 L1-norm보다 훨씬 큰 오차 (e vs e ^ 2)를 보게되므로 훨씬 더 민감합니다. 따라서 오류를 최소화하기 위해 모델을 조정해줍니다.
# * C는 estimator 입니다. logspace 1차원 10개 배열로 0에서 4까지를 estimator로 놓은 것입니다.

# %%
penalty = ['l1', 'l2']
C = np.logspace(0, 4, 10)

hyperparams = {'penalty': penalty, 'C': C}

gd=GridSearchCV(estimator = LogisticRegression(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### XGBoost Step 1.

# %%
learning_rate = [0.001, 0.005, 0.01, 0.05, 0.1, 0.2]
n_estimators = [10, 50, 100, 250, 500, 1000]

hyperparams = {'learning_rate': learning_rate, 'n_estimators': n_estimators}

gd=GridSearchCV(estimator = XGBClassifier(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### XGB Step 2.

# %%
max_depth = [3, 4, 5, 6, 7, 8, 9, 10]
min_child_weight = [1, 2, 3, 4, 5, 6]

hyperparams = {'max_depth': max_depth, 'min_child_weight': min_child_weight}

gd=GridSearchCV(estimator = XGBClassifier(learning_rate=0.2, n_estimators=10), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### XGB Step 3.

# %%
gamma = [i*0.1 for i in range(0,5)]

hyperparams = {'gamma': gamma}

gd=GridSearchCV(estimator = XGBClassifier(learning_rate=0.2, n_estimators=10, max_depth=6, 
                                          min_child_weight=1), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### XGB Step 4

# %%
subsample = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1]
colsample_bytree = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1]
    
hyperparams = {'subsample': subsample, 'colsample_bytree': colsample_bytree}

gd=GridSearchCV(estimator = XGBClassifier(learning_rate=0.2, n_estimators=10, max_depth=6, 
                                          min_child_weight=1, gamma=0), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### XGB Step 5

# %%
reg_alpha = [1e-5, 1e-2, 0.1, 1, 100]
    
hyperparams = {'reg_alpha': reg_alpha}

gd=GridSearchCV(estimator = XGBClassifier(learning_rate=0.2, n_estimators=10, max_depth=6, 
                                          min_child_weight=1, gamma=0, subsample=1, colsample_bytree=1),
                                         param_grid = hyperparams, verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### Gaussian Process

# %%
n_restarts_optimizer = [0, 1, 2, 3]
max_iter_predict = [1, 2, 5, 10, 20, 35, 50, 100]
warm_start = [True, False]

hyperparams = {'n_restarts_optimizer': n_restarts_optimizer, 'max_iter_predict': max_iter_predict, 'warm_start': warm_start}

gd=GridSearchCV(estimator = GaussianProcessClassifier(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### Adaboost.

# %%
n_estimators = [10, 100, 200, 500]
learning_rate = [0.001, 0.01, 0.1, 0.5, 1, 1.5, 2]

hyperparams = {'n_estimators': n_estimators, 'learning_rate': learning_rate}

gd=GridSearchCV(estimator = AdaBoostClassifier(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### KNN

# %%
n_neighbors = [1, 2, 3, 4, 5]
algorithm = ['auto']
weights = ['uniform', 'distance']
leaf_size = [1, 2, 3, 4, 5, 10]

hyperparams = {'algorithm': algorithm, 'weights': weights, 'leaf_size': leaf_size, 
               'n_neighbors': n_neighbors}

gd=GridSearchCV(estimator = KNeighborsClassifier(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

# Fitting model and return results
gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### Random Forest.

# %%
n_estimators = [10, 50, 100, 200]
max_depth = [3, None]
max_features = [0.1, 0.2, 0.5, 0.8]
min_samples_split = [2, 6]
min_samples_leaf = [2, 6]

hyperparams = {'n_estimators': n_estimators, 'max_depth': max_depth, 'max_features': max_features,
               'min_samples_split': min_samples_split, 'min_samples_leaf': min_samples_leaf}

gd=GridSearchCV(estimator = RandomForestClassifier(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### Extra Trees

# %%
n_estimators = [10, 25, 50, 75, 100]
max_depth = [3, None]
max_features = [0.1, 0.2, 0.5, 0.8]
min_samples_split = [2, 10]
min_samples_leaf = [2, 10]

hyperparams = {'n_estimators': n_estimators, 'max_depth': max_depth, 'max_features': max_features,
               'min_samples_split': min_samples_split, 'min_samples_leaf': min_samples_leaf}

gd=GridSearchCV(estimator = ExtraTreesClassifier(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# ### Bagging Classifier

# %%
n_estimators = [10, 50, 75, 100, 200]
max_samples = [0.1, 0.2, 0.5, 0.8, 1.0]
max_features = [0.1, 0.2, 0.5, 0.8, 1.0]

hyperparams = {'n_estimators': n_estimators, 'max_samples': max_samples, 'max_features': max_features}

gd=GridSearchCV(estimator = BaggingClassifier(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy", n_jobs=-1)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)

# %% [markdown]
# <a id = "part10"></a>
# ## Part 10: 모델 재 트레이닝
# [Go to the Table of Contents](#table_of_contents)

# %%
# 튜닝 모델 시작
# sample을 split하는 것은 전체데이터 80%를 트레인셋에 20%는 테스트셋에 줌  
ran = RandomForestClassifier(max_depth=None, max_features=0.1, min_samples_leaf=2, min_samples_split=2, n_estimators=50, random_state=1)

knn = KNeighborsClassifier(leaf_size=1, n_neighbors=4, weights='distance')

log = LogisticRegression(C=2.7825594022071245, penalty='l2')

xgb = XGBClassifier(learning_rate=0.1, n_estimators=10, max_depth=7, 
                                          min_child_weight=5, gamma=0, subsample=1, colsample_bytree=1, reg_alpha=1e-05)

gbc = GradientBoostingClassifier(learning_rate=0.1, max_depth=3, n_estimators=1000)

svc = SVC(probability=True, gamma=0.001, C=5)

ext = ExtraTreesClassifier(max_depth=None, max_features=0.2, min_samples_leaf=10, min_samples_split=2, n_estimators=100, random_state=1)

ada = AdaBoostClassifier(learning_rate=0.5, n_estimators=500, random_state=1)

gpc = GaussianProcessClassifier(max_iter_predict=1, n_restarts_optimizer=0, warm_start=True)

bag = BaggingClassifier(max_features=1.0, max_samples=1.0, n_estimators=75, random_state=1)

# 리스트
models = [ran, knn, log, xgb, gbc, svc, ext, ada, gnb, gpc, bag]         
model_names = ['Random Forest', 'K Nearest Neighbour', 'Logistic Regression', 'XGBoost', 'Gradient Boosting', 'SVC', 'Extra Trees', 'AdaBoost', 'Gaussian Naive Bayes', 'Gaussian Process', 'Bagging Classifier']
scores3 = {}

# Sequentially fit and cross validate all models
for ind, mod in enumerate(models):
    mod.fit(X_train, y_train)
    acc = cross_val_score(mod, X_train, y_train, scoring = "accuracy", cv = 10)
    scores3[model_names[ind]] = acc

# %%
results = pd.DataFrame(scores).T
results['mean'] = results.mean(1)
result_df = results.sort_values(by='mean', ascending=False)
result_df.head(11)


result_df = result_df.drop(['mean'], axis=1)
sns.boxplot(data=result_df.T, orient='h')
plt.title('Machine Learning Algorithm Accuracy Score \n')
plt.xlabel('Accuracy Score (%)');

# %% [markdown]
# <a id = "part11"></a>
# ## Part 11: 마지막 보팅
# [Go to the Table of Contents](#table_of_contents)

# %%
#튜닝한 파라미터로 하드보팅
grid_hard = VotingClassifier(estimators = [('Random Forest', ran), 
                                           ('Logistic Regression', log),
                                           ('XGBoost', xgb),
                                           ('Gradient Boosting', gbc),
                                           ('Extra Trees', ext),
                                           ('AdaBoost', ada),
                                           ('Gaussian Process', gpc),
                                           ('SVC', svc),
                                           ('K Nearest Neighbour', knn),
                                           ('Bagging Classifier', bag)], voting = 'hard')

grid_hard_cv = model_selection.cross_validate(grid_hard, X_train, y_train, cv=10)
grid_hard.fit(X_train, y_train)

print("Hard voting on test set score mean: {:.2f}". format(grid_hard_cv['test_score'].mean() * 100))

# %%
grid_soft = VotingClassifier(estimators = [('Random Forest', ran), 
                                           ('Logistic Regression', log),
                                           ('XGBoost', xgb),
                                           ('Gradient Boosting', gbc),
                                           ('Extra Trees', ext),
                                           ('AdaBoost', ada),
                                           ('Gaussian Process', gpc),
                                           ('SVC', svc),
                                           ('K Nearest Neighbour', knn),
                                           ('Bagging Classifier', bag)], voting = 'soft')

grid_soft_cv = model_selection.cross_validate(grid_soft, X_train, y_train, cv=10)
grid_soft.fit(X_train, y_train)

print("Soft voting on test set score mean: {:.2f}". format(grid_soft_cv['test_score'].mean() * 100))

# %% [markdown]
# <a id = "part12"></a>
# ## Part 12: 마지막 모델 예측
# [Go to the Table of Contents](#table_of_contents)

# %%
# Final predictions2
predictions = grid_hard.predict(X_test)

submission = pd.concat([pd.DataFrame(passId), pd.DataFrame(predictions)], axis = 'columns')

submission.columns = ["PassengerId", "Survived"]
submission.to_csv('titanic_submission1.csv', header = True, index = False)

# %%
# Final predictions
predictions = grid_soft.predict(X_test)

submission = pd.concat([pd.DataFrame(passId), pd.DataFrame(predictions)], axis = 'columns')

submission.columns = ["PassengerId", "Survived"]
submission.to_csv('titanic_submission2.csv', header = True, index = False)

# %% [markdown]
# <a id = "part13"></a>
# ## Part 13: 제출
# [Go to the Table of Contents](#table_of_contents)

# %%
# And we finally make a submission 그리고 제출 합니다.
# Please make sure you "commit" (It take a few minutes) / commit버턴을 누르시는 것을 잊지 마세요 (몇 분 걸립니다)
# And then you will see the submission file on the top right hand side at Data>Output>Kaggle/working / 그럼 우측 상단 데이터 아웃풋에서 제출용 결과물이 나올 것입니다.
